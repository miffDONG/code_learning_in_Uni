# %%
import pandas as pd
import re
import numpy as np
import random

# %%
ori_train_df = pd.read_csv('../../patent_baseline/train.csv')
train_df = ori_train_df.copy()

# %% [markdown]
# # 모양 처리
# form_entity : 모양과 관련된 기호를 추가했습니다
# form_sub_entity : 형상, 형 etc...
#
# regex_form() 함수를 사용하면 모양관련 처리가 됩니다.

# %% [markdown]
# ## 사용하실 때 복사해야 할 부분
# form_entity , form_sub_entity, regex_form() 있는 페이지
#
# ex) train_df['abstract'] = train_df['abstract'].apply(lambda x: regex_form(x))

# %%
form_entity = """
∧
⊥
┘
┗
□
┳
∃
╋
┛
†
ㅜ
┌
ㅗ
└
L
┐
┓
┏
┣
∠
￢
┍
┚
Π
╉
Ⅰ
|
ㅣ
Ｉ
｜
ㅒ
ㅡ
━
ㅓ
─
∞
／
＼
V
+
⊂
<
(
〈
〔
""".split('\n')[1:-1]

form_sub_entity = """
형태
모양
형상
형사
형
자
""".split('\n')[1:-1]

# %%
def find_special_form(text, form_entity):
    find = any(special in text for special in form_entity)
    return [find, text]  # Return a list with the result and text

form_abstract = train_df['abstract'].apply(lambda x: find_special_form(x, form_entity))

# Convert the result to a DataFrame with columns 'find' and 'text'
form_abstract = pd.DataFrame(form_abstract.tolist(), columns=['find', 'abstract'])

# %%
form_abstract['abstract'][1196]
# Out:
# '본고안은 포장용상자에 관한 것이다.더욱 상세하게는 포장상자의 옆판에 상부는 절첩되어있고 하부는 벌어져있는 상태로 형성된 ∧ 형의 절곡부를 구성하여 포장상자내의 내용물이 안쪽에서 밀어주는 작용을 하므로서 상자내의 내용물이 쏟아지지 않으며,또한 뚜껑부에 손잡이와 일체로 형성된 체결부위가 체결공에 밑으로부터 위쪽으로 체결되는 체결방법으로인하여 체결공에 체결된 체결부위가 이탈되지 않토록 구성된 것이다.'

# %%
form_temp = form_abstract[form_abstract['find'] == True]
idx_form = form_temp.index.tolist()
print(idx_form)
# Out:
# [2, 5, 7, 23, 80, 81, 103, 117, 119, 163, 193, 209, 235, 267, 311, 323, 335, 350, 364, 375, 386, 387, 403, 413, 426, 440, 448, 477, 502, 518, 525, 548, 586, 596, 600, 605, 608, 620, 662, 668, 676, 684, 706, 718, 743, 764, 777, 804, 808, 826, 836, 837, 850, 864, 865, 866, 878, 944, 967, 986, 987, 1053, 1076, 1151, 1159, 1163, 1187, 1196, 1203, 1245, 1250, 1252, 1303, 1341, 1343, 1368, 1388, 1403, 1404, 1434, 1471, 1481, 1503, 1535, 1554, 1560, 1561, 1565, 1582, 1616, 1636, 1646, 1718, 1722, 1729, 1739, 1748, 1770, 1790, 1796, 1801, 1825, 1842, 1854, 1870, 1955, 1983, 1988, 1994, 2015, 2018, 2022, 2102, 2119, 2128, 2130, 2134, 2137, 2155, 2198, 2226, 2243, 2263, 2292, 2300, 2338, 2344, 2363, 2417, 2425, 2427, 2429, 2432, 2470, 2477, 2478, 2479, 2524, 2540, 2550, 2554, 2566, 2569, 2596, 2633, 2641, 2653, 2668, 2692, 2708, 2734, 2743, 2787, 2801, 2818, 2833, 2908, 2918, 2928, 2937, 2965, 2988, 2991, 3010, 3020, 3021, 3054, 3085, 3104, 3108, 3117, 3120, 3135, 3136, 3144, 3162, 3190, 3192, 3204, 3216, 3237, 3285, 3288, 3289, 3306, 3330, 3341, 3362, 3376, 3385, 3394, 3402, 3414, 3416, 3465, 3490, 3503, 3530, 3555, 3556, 3575, 3591, 3612, 3625, 3666, 3688, 3709, 3714, 3741, 3765, 3771, 3780, 3811, 3841, 3842, 3850, 3945, 3961, 3970, 3973, 3976, 3984, 4016, 4063, 4075, 4077, 4108, 4112, 4136, 4174, 4209, 4219, 4231, 4295, 4319, 4320, 4343, 4345, 4365, 4380, 4393, 4395, 4400, 4404, 4405, 4422, 4464, 4481, 4486, 4488, 4504, 4509, 4516, 4517, 4547, 4549, 4567, 4573, 4583, 4604, 4639, 4658, 4730, 4736, 4777, 4824, 4875, 4888, 4890, 4906, 4917, 4950, 4965, 5018, 5023, 5038, 5041, 5043, 5124, 5128, 5134, 5157, 5187, 5219, 5246, 5252, 5412, 5417, 5436, 5444, 5460, 5468, 5484, 5496, 5518, 5562, 5583, 5586, 5617, 5623, 5660, 5675, 5681, 5700, 5728, 5743, 5746, 5748, 5786, 5800, 5802, 5817, 5838, 5844, 5853, 5868, 5874, 5875, 5880, 5901, 5907, 5934, 5958, 5991, 6091, 6102, 6122, 6124, 6136, 6140, 6146, 6147, 6156, 6214, 6268, 6269, 6277, 6278, 6287, 6304, 6312, 6330, 6340, 6342, 6391, 6394, 6397, 6485, 6507, 6519, 6525, 6564, 6573, 6592, 6595, 6596, 6648, 6677, 6704, 6721, 6732, 6736, 6741, 6754, 6780, 6785, 6787, 6802, 6807, 6829, 6849, 6857, 6880, 6899, 6920, 6927, 6940, 6948, 6957, 6981, 6996, 6998, 7058, 7103, 7118, 7137, 7201, 7202, 7205, 7207, 7220, 7225, 7261, 7277, 7291, 7315, 7322, 7365, 7366, 7379, 7434, 7462, 7537, 7541, 7552, 7565, 7600, 7605, 7634, 7642, 7668, 7671, 7676, 7678, 7679, 7716, 7728, 7736, 7742, 7769, 7794, 7803, 7841, 7848, 7893, 7898, 7900, 7918, 7926, 7936, 7988, 7995, 8039, 8042, 8046, 8053, 8122, 8128, 8134, 8136, 8151, 8157, 8172, 8196, 8201, 8281, 8282, 8283, 8286, 8296, 8301, 8303, 8304, 8306, 8310, 8397, 8405, 8456, 8463, 8464, 8475, 8490, 8494, 8513, 8541, 8553, 8566, 8600, 8626, 8640, 8649, 8661, 8714, 8745, 8763, 8809, 8814, 8818, 8819, 8824, 8839, 8879, 8884, 8889, 8940, 8950, 8952, 8954, 8958, 8961, 8963, 8965, 8971, 8980, 8999, 9039, 9052, 9069, 9103, 9110, 9114, 9132, 9156, 9184, 9193, 9206, 9225, 9245, 9290, 9310, 9342, 9369, 9409, 9432, 9443, 9472, 9492, 9505, 9520, 9528, 9585, 9617, 9625, 9635, 9654, 9667, 9672, 9675, 9709, 9733, 9762, 9763, 9801, 9944, 9950, 9955, 10018, 10045, 10046, 10056, 10068, 10094, 10107, 10121, 10123, 10126, 10156, 10160, 10165, 10191, 10203, 10205, 10237, 10281, 10326, 10361, 10407, 10423, 10424, 10446, 10454, 10456, 10489, 10490, 10497, 10508, 10561, 10608, 10629, 10644, 10726, 10732, 10733, 10760, 10782, 10785, 10789, 10791, 10793, 10821, 10837, 10850, 10870, 10877, 10880, 10931, 10939, 10942, 10955, 10962, 10981, 10983, 10984, 10989, 11015, 11042, 11083, 11128, 11149, 11188, 11213, 11218, 11222, 11238, 11246, 11282, 11289, 11297, 11332, 11352, 11413, 11438, 11552, 11565, 11600, 11601, 11643, 11657, 11676, 11696, 11723, 11778, 11784, 11795, 11813, 11819, 11851, 11865, 11868, 11871, 11873, 11890, 11896, 11918, 11925, 11955, 11959, 11971, 12024, 12037, 12080, 12094, 12115, 12118, 12120, 12140, 12163, 12169, 12187, 12241, 12260, 12291, 12292, 12299, 12343, 12358, 12363, 12384, ...

# %%
# # 정규표현식 패턴 생성
pattern_form = '|'.join(re.escape(symbol) for symbol in form_entity)
pattern_sub = '|'.join(text for text in form_sub_entity)

# 패턴에 매치되는 부분 찾기
def find_form(pattern,text):
    arr = []
    matches = re.finditer(pattern, text)

    #결과 출력
    for match in matches:
        arr.append([match.start(),match.end()])
        # print(f"기호 '{match.group()}'이(가) 발견된 위치: {match.start()}-{match.end()}")
    return arr

def regex_form(text):
    new_Text = "모양"
    modified_text = text
    del_len = 0
    try:
        # 기호 , 단어 위치 찾기
        matches_form = find_form(pattern_form,text)
        matches_sub = find_form(pattern_sub,text)
        # 단어가 기호의 마지막 index + 5 이내에 있으면 출력
        for match_form in matches_form:
            for match_sub in matches_sub:
                if match_form[0] <= match_sub[1] <= match_form[1]+5:
                    start = match_form[0] - del_len
                    end = match_sub[1] - del_len
                    print(f"범위 {match_form[0]}~{match_sub[1]}")
                    modified_text = modified_text[:start] + new_Text + modified_text[end:]
                    del_len = del_len + (match_sub[1] - match_form[0]+1) - len(new_Text) - 1
                    break
    except:
        modified_text = text        
    return modified_text

# # # test
# print(regex_form(form_temp['abstract'][1955]))
# print(form_temp['abstract'][1955])
print(regex_form("본 고안은 다목적 증기 온수 발생장치에서 증기 또는 온수가 배출되는 호스 단부에 자바라 형태의 주름부를 형성하고, 주름부의 최선단에 구형(求刑)이나 반구형(半球形) 또는 이와 유사한 외면 형상의 노즐을 형성하거나 설치하여 ┛ 형상, ┳ 형상, ╋ 형사, ⊂ 형상, 〈 형상, 〔 형상, ∃ 형상 등의 직각관이나 꺽임이 심한 곡선관, 관체의 단턱부, 또는 엘보(elbow)부분에도 쉽게 삽입시켜 해빙(解氷)할 수 있도록 한 것이다."))
# Out:
# 범위 76~76
# 범위 86~86
# 범위 124~128
# 범위 130~134
# 범위 136~140
# 범위 142~146
# 범위 148~152
# 범위 154~158
# 범위 160~164
# 본 고안은 다목적 증기 온수 발생장치에서 증기 또는 온수가 배출되는 호스 단부에 자바라 형태의 주름부를 형성하고, 주름부의 최선단에 구형모양(求刑)이나 반구형모양(半球形) 또는 이와 유사한 외면 형상의 노즐을 형성하거나 설치하여 모양, 모양, 모양, 모양, 모양, 모양, 모양 등의 직각관이나 꺽임이 심한 곡선관, 관체의 단턱부, 또는 엘보(elbow)부분에도 쉽게 삽입시켜 해빙(解氷)할 수 있도록 한 것이다.

# %%
form_temp['extrected'] = form_temp['abstract'].apply(lambda x: regex_form(x))
# Out:
# 범위 120~122
# 범위 177~179
# 범위 244~246
# 범위 361~363
# 범위 99~102
# 범위 134~140
# 범위 67~70
# 범위 105~108
# 범위 219~222
# 범위 235~238
# 범위 135~137
# 범위 121~123
# 범위 15~20
# 범위 69~75
# 범위 189~192
# 범위 251~254
# 범위 267~269
# 범위 366~369
# 범위 429~432
# 범위 445~447
# 범위 283~285
# 범위 29~31
# 범위 467~469
# 범위 122~125
# 범위 171~177
# 범위 173~177
# 범위 541~546
# 범위 543~546
# 범위 500~504
# 범위 36~40
# 범위 154~156
# 범위 324~326
# 범위 144~146
# 범위 161~164
# 범위 69~72
# 범위 263~266
# 범위 284~287
# 범위 288~290
# 범위 446~451
# 범위 74~76
# 범위 82~84
# 범위 235~237
# 범위 69~71
# 범위 299~301
# 범위 411~413
# 범위 181~185
# 범위 190~192
# 범위 272~274
# 범위 284~286
# 범위 367~369
# 범위 506~508
# 범위 200~202
# 범위 257~259
# 범위 375~377
# 범위 504~506
# 범위 565~567
# 범위 468~470
# 범위 96~98
# 범위 211~213
# 범위 404~407
# 범위 529~532
# 범위 273~275
# 범위 116~120
# 범위 18~23
# 범위 169~171
# 범위 247~249
# 범위 171~177
# 범위 587~593
# 범위 206~208
# 범위 258~260
# 범위 561~563
# 범위 604~606
# 범위 316~321
# 범위 472~474
# 범위 205~207
# 범위 248~250
# 범위 357~359
# 범위 183~185
# 범위 177~181
# 범위 135~138
# 범위 221~224
# 범위 297~300
# 범위 75~79
# 범위 60~64
# 범위 453~455
# 범위 490~492
# 범위 18~20
# 범위 269~271
# 범위 303~305
# 범위 103~109
# 범위 153~158
# 범위 221~223
# 범위 353~355
# 범위 185~187
# 범위 93~95
# 범위 253~255
# 범위 368~370
# 범위 328~330
# 범위 97~99
# 범위 176~179
# 범위 406~410
# 범위 786~789
# 범위 288~290
# 범위 83~85
# 범위 103~105
# 범위 392~397
# 범위 159~163
# 범위 276~278
# 범위 115~119
# 범위 121~125
# 범위 127~131
# 범위 133~137
# 범위 139~143
# 범위 145~149
# 범위 151~155
# 범위 45~47
# 범위 61~63
# 범위 143~145
# 범위 292~294
# 범위 266~268
# 범위 388~390
# 범위 192~194
# 범위 52~56
# 범위 45~47
# 범위 61~63
# 범위 143~145
# 범위 179~181
# 범위 380~382
# 범위 205~207
# 범위 491~494
# 범위 63~66
# 범위 76~79
# 범위 276~278
# 범위 109~111
# 범위 51~53
# 범위 334~336
# 범위 352~354
# 범위 394~396
# 범위 457~459
# 범위 628~630
# 범위 319~322
# 범위 637~639
# 범위 890~892
# 범위 361~363
# 범위 7~12
# 범위 134~139
# 범위 194~199
# 범위 1236~1241
# 범위 51~54
# 범위 11~13
# 범위 258~260
# 범위 343~345
# 범위 28~30
# 범위 87~89
# 범위 408~410
# 범위 43~45
# 범위 214~217
# 범위 359~361
# 범위 132~134
# 범위 214~217
# 범위 376~378
# 범위 546~548
# 범위 49~54
# 범위 25~27
# 범위 127~129
# 범위 233~235
# 범위 94~96
# 범위 111~113
# 범위 252~254
# 범위 149~151
# 범위 124~126
# 범위 181~183
# 범위 207~209
# 범위 301~303
# 범위 662~664
# 범위 711~713
# 범위 785~787
# 범위 202~207
# 범위 279~281
# 범위 247~249
# 범위 436~440
# 범위 107~111
# 범위 122~126
# 범위 178~182
# 범위 100~102
# 범위 153~156
# 범위 267~270
# 범위 84~86
# 범위 301~303
# 범위 61~65
# 범위 233~239
# 범위 102~104
# 범위 168~170
# 범위 98~100
# 범위 302~304
# 범위 218~223
# 범위 134~137
# 범위 9~12
# 범위 91~93
# 범위 304~306
# 범위 76~78
# 범위 96~98
# 범위 338~340
# 범위 176~178
# 범위 297~299
# 범위 143~146
# 범위 444~447
# 범위 132~136
# 범위 167~171
# 범위 239~242
# 범위 197~199
# 범위 298~302
# 범위 360~363
# 범위 453~456
# 범위 502~506
# 범위 516~519
# 범위 57~60
# 범위 11~13
# 범위 99~101
# 범위 369~371
# 범위 132~138
# 범위 272~274
# 범위 244~248
# 범위 242~245
# 범위 433~435
# 범위 444~449
# 범위 445~449
# 범위 215~218
# 범위 8~12
# 범위 47~50
# 범위 172~178
# 범위 225~227
# 범위 463~465
# 범위 371~377
# 범위 372~377
# 범위 264~266
# 범위 122~125
# 범위 21~27
# 범위 96~96
# 범위 71~74
# 범위 116~119
# 범위 250~253
# 범위 134~136
# 범위 259~261
# 범위 15~19
# 범위 123~127
# 범위 220~224
# 범위 258~262
# 범위 279~283
# 범위 343~347
# 범위 10~12
# 범위 97~103
# 범위 106~112
# 범위 63~69
# 범위 93~99
# 범위 63~69
# 범위 93~99
# 범위 318~322
# 범위 208~211
# 범위 32~35
# 범위 80~82
# 범위 203~205
# 범위 195~197
# 범위 311~313
# 범위 152~157
# 범위 339~341
# 범위 374~376
# 범위 534~539
# 범위 8~10
# 범위 143~145
# 범위 168~170
# 범위 15~20
# 범위 39~44
# 범위 584~589
# 범위 237~239
# 범위 89~91
# 범위 339~342
# 범위 231~234
# 범위 441~443
# 범위 406~410
# 범위 407~410
# 범위 148~153
# 범위 386~388
# 범위 64~70
# 범위 65~70
# 범위 282~284
# 범위 438~440
# 범위 322~328
# 범위 282~286
# 범위 283~286
# 범위 235~239
# 범위 27~29
# 범위 297~303
# 범위 463~465
# 범위 222~225
# 범위 199~201
# 범위 340~342
# 범위 359~362
# 범위 80~86
# 범위 272~277
# 범위 337~342
# 범위 375~380
# 범위 376~380
# 범위 793~799
# 범위 69~75
# 범위 103~109
# 범위 129~134
# 범위 30~32
# 범위 289~291
# 범위 221~227
# 범위 77~79
# 범위 43~48
# 범위 410~412
# 범위 130~136
# 범위 64~70
# 범위 100~106
# 범위 144~150
# 범위 265~271
# 범위 8~13
# 범위 469~473
# 범위 470~473
# 범위 496~500
# 범위 497~500
# 범위 283~288
# 범위 284~288
# 범위 429~431
# 범위 28~34
# 범위 92~94
# 범위 36~42
# 범위 19~24
# 범위 141~145
# 범위 196~200
# 범위 238~242
# 범위 225~228
# 범위 23~25
# 범위 336~338
# 범위 265~267
# 범위 117~123
# 범위 118~123
# 범위 239~244
# 범위 368~374
# 범위 36~39
# 범위 493~499
# 범위 602~608
# 범위 15~21
# 범위 222~227
# 범위 223~227
# 범위 463~467
# 범위 599~601
# 범위 214~216
# 범위 190~194
# 범위 30~36
# 범위 157~163
# 범위 246~252
# 범위 400~402
# 범위 448~450
# 범위 529~531
# 범위 541~543
# 범위 12~18
# 범위 139~145
# 범위 28~30
# 범위 293~297
# 범위 294~297
# 범위 158~161
# 범위 149~151
# 범위 210~212
# 범위 40~42
# 범위 24~29
# 범위 7~13
# 범위 99~104
# 범위 37~43
# 범위 222~224
# 범위 277~279
# 범위 876~881
# 범위 877~881
# 범위 672~674
# 범위 756~758
# 범위 128~130
# 범위 329~335
# 범위 235~237
# 범위 211~214
# 범위 215~218
# 범위 380~383
# 범위 21~23
# 범위 205~207
# 범위 401~403
# 범위 116~121
# 범위 117~121
# 범위 229~232
# 범위 368~371
# 범위 378~381
# 범위 451~454
# 범위 495~499
# 범위 127~129
# 범위 97~99
# 범위 534~536
# 범위 311~314
# 범위 350~352
# 범위 428~430
# 범위 231~233
# 범위 439~443
# 범위 528~532
# 범위 113~116
# 범위 207~210
# 범위 43~45
# 범위 179~185
# 범위 211~217
# 범위 107~113
# 범위 339~341
# 범위 428~430
# 범위 591~593
# 범위 518~521
# 범위 244~247
# 범위 355~358
# 범위 250~254
# 범위 79~81
# 범위 90~92
# 범위 141~143
# 범위 48~50
# 범위 53~55
# 범위 453~455
# 범위 461~463
# 범위 222~228
# 범위 114~119
# 범위 280~282
# 범위 60~62
# 범위 90~92
# 범위 471~473
# 범위 14~18
# 범위 15~18
# 범위 308~310
# 범위 60~62
# 범위 90~92
# 범위 698~702
# 범위 699~702
# 범위 25~28
# 범위 119~122
# 범위 145~148
# 범위 160~163
# 범위 272~275
# 범위 317~320
# 범위 329~332
# 범위 360~363
# 범위 133~137
# 범위 134~137
# 범위 172~174
# 범위 264~266
# 범위 181~187
# 범위 52~54
# 범위 195~197
# 범위 80~82
# 범위 0~2
# 범위 166~168
# 범위 693~695
# 범위 901~903
# 범위 1972~1978
# 범위 554~560
# 범위 265~268
# 범위 26~31
# 범위 27~31
# 범위 287~290
# 범위 303~308
# 범위 340~345
# 범위 101~104
# 범위 237~239
# 범위 246~249
# 범위 247~249
# 범위 71~76
# 범위 407~410
# 범위 0~2
# 범위 72~75
# 범위 545~547
# 범위 775~777
# 범위 143~145
# 범위 125~129
# 범위 478~482
# 범위 304~306
# 범위 1058~1060
# 범위 304~307
# 범위 209~214
# 범위 232~237
# 범위 278~283
# 범위 307~312
# 범위 73~78
# 범위 169~174
# 범위 94~96
# 범위 133~135
# 범위 328~331
# 범위 158~160
# 범위 311~315
# 범위 15~20
# 범위 115~117
# 범위 339~341
# 범위 356~358
# 범위 53~58
# 범위 136~138
# 범위 572~574
# 범위 210~215
# 범위 139~141
# 범위 0~6
# 범위 67~73
# 범위 187~193
# 범위 366~372
# 범위 6~10
# 범위 449~451
# 범위 309~311
# 범위 289~293
# 범위 640~642
# 범위 276~280
# 범위 386~389
# 범위 68~74
# 범위 84~90
# 범위 214~220
# 범위 256~262
# 범위 329~335
# 범위 344~350
# 범위 96~98
# 범위 184~186
# 범위 274~276
# 범위 350~352
# 범위 631~633
# 범위 643~645
# 범위 376~379
# 범위 58~61
# 범위 269~272
# 범위 407~413
# 범위 419~425
# 범위 433~439
# 범위 472~478
# 범위 486~492
# 범위 556~559
# 범위 695~701
# 범위 116~118
# 범위 131~133
# 범위 150~155
# 범위 106~108
# 범위 124~126
# 범위 177~179
# 범위 177~182
# 범위 279~281
# 범위 393~395
# 범위 413~415
# 범위 466~468
# 범위 365~367
# 범위 678~680
# 범위 130~136
# 범위 92~95
# 범위 232~235
# 범위 40~45
# 범위 81~86
# 범위 103~105
# 범위 253~255
# 범위 186~192
# 범위 739~741
# 범위 81~83
# 범위 939~943
# 범위 940~943
# 범위 256~260
# 범위 362~366
# 범위 462~468
# 범위 677~683
# 범위 7~13
# 범위 32~34
# 범위 177~179
# 범위 158~163
# 범위 198~203
# 범위 687~692
# 범위 1113~1115
# C:\Users\hyundong\AppData\Local\Temp\ipykernel_21668\3180563456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   form_temp['extrected'] = form_temp['abstract'].apply(lambda x: regex_form(x))

# %%
form_temp['extrected'][1196]
# Out:
# '본고안은 포장용상자에 관한 것이다.더욱 상세하게는 포장상자의 옆판에 상부는 절첩되어있고 하부는 벌어져있는 상태로 형성된 모양의 절곡부를 구성하여 포장상자내의 내용물이 안쪽에서 밀어주는 작용을 하므로서 상자내의 내용물이 쏟아지지 않으며,또한 뚜껑부에 손잡이와 일체로 형성된 체결부위가 체결공에 밑으로부터 위쪽으로 체결되는 체결방법으로인하여 체결공에 체결된 체결부위가 이탈되지 않토록 구성된 것이다.'

# %%
form_check = form_temp.drop('abstract',axis=1)
form_check.to_csv('./text.csv')
