# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./ad_10000records.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  10000 non-null  float64
#  1   Age                       10000 non-null  float64
#  2   Area Income               10000 non-null  float64
#  3   Daily Internet Usage      10000 non-null  float64
#  4   Ad Topic Line             10000 non-null  object
#  5   City                      10000 non-null  object
#  6   Gender                    10000 non-null  object
#  7   Country                   10000 non-null  object
#  8   Timestamp                 10000 non-null  object
#  9   Clicked on Ad             10000 non-null  int64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#        Daily Time Spent on Site           Age   Area Income  \
# count              10000.000000  10000.000000  10000.000000
# mean                  61.660757     35.940100  53840.047721
# std                   15.704142      8.572973  13343.708718
# min                   32.600000     19.000000  13996.500000
# 25%                   48.860000     29.000000  44052.302500
# 50%                   59.590000     35.000000  56180.930000
# 75%                   76.580000     42.000000  61840.260000
# max                   90.970000     60.000000  79332.330000
#
#        Daily Internet Usage  Clicked on Ad
# count          10000.000000   10000.000000
# mean             177.759831       0.491700
# std               40.820951       0.499956
# min              105.220000       0.000000
# 25%              140.150000       0.000000
# 50%              178.920000       0.000000
# 75%              212.670000       1.000000
# max              269.960000       1.000000

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_')

# %%
df
# Out:
#       daily_time_spent_on_site   age  area_income  daily_internet_usage  \
# 0                        62.26  32.0     69481.85                172.83
# 1                        41.73  31.0     61840.26                207.17
# 2                        44.40  30.0     57877.15                172.83
# 3                        59.88  28.0     56180.93                207.17
# 4                        49.21  30.0     54324.73                201.58
# ...                        ...   ...          ...                   ...
# 9995                     41.73  31.0     61840.26                207.17
# 9996                     41.73  28.0     51501.38                120.49
# 9997                     55.60  39.0     38067.08                124.44
# 9998                     46.61  50.0     43974.49                123.13
# 9999                     46.61  43.0     60575.99                198.45
#
#                                ad_topic_line             city  gender  \
# ...

# %% [markdown]
# df

# %%
sns.boxenplot(data=df,y='area_income',x='clicked_on_ad')
# Out:
# c:\Users\hyundong\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\hyundong\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='clicked_on_ad', ylabel='area_income'>

# %%
sns.displot(df['area_income'])
# Out:
# c:\Users\hyundong\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['area_income_group'] = df['area_income']//10000
df
# Out:
#       daily_time_spent_on_site   age  area_income  daily_internet_usage  \
# 0                        62.26  32.0     69481.85                172.83
# 1                        41.73  31.0     61840.26                207.17
# 2                        44.40  30.0     57877.15                172.83
# 3                        59.88  28.0     56180.93                207.17
# 4                        49.21  30.0     54324.73                201.58
# ...                        ...   ...          ...                   ...
# 9995                     41.73  31.0     61840.26                207.17
# 9996                     41.73  28.0     51501.38                120.49
# 9997                     55.60  39.0     38067.08                124.44
# 9998                     46.61  50.0     43974.49                123.13
# 9999                     46.61  43.0     60575.99                198.45
#
#                                ad_topic_line             city  gender  \
# ...

# %%
df['area_income_group_new'] = df['area_income']//10000
# Out:
#       daily_time_spent_on_site   age  area_income  daily_internet_usage  \
# 0                        62.26  32.0     69481.85                172.83
# 1                        41.73  31.0     61840.26                207.17
# 2                        44.40  30.0     57877.15                172.83
# 3                        59.88  28.0     56180.93                207.17
# 4                        49.21  30.0     54324.73                201.58
# ...                        ...   ...          ...                   ...
# 9995                     41.73  31.0     61840.26                207.17
# 9996                     41.73  28.0     51501.38                120.49
# 9997                     55.60  39.0     38067.08                124.44
# 9998                     46.61  50.0     43974.49                123.13
# 9999                     46.61  43.0     60575.99                198.45
#
#                                ad_topic_line             city  gender  \
# ...

# %%
df = df.drop(columns='area_income_group_new')
df
# Out:
#       daily_time_spent_on_site   age  area_income  daily_internet_usage  \
# 0                        62.26  32.0     69481.85                172.83
# 1                        41.73  31.0     61840.26                207.17
# 2                        44.40  30.0     57877.15                172.83
# 3                        59.88  28.0     56180.93                207.17
# 4                        49.21  30.0     54324.73                201.58
# ...                        ...   ...          ...                   ...
# 9995                     41.73  31.0     61840.26                207.17
# 9996                     41.73  28.0     51501.38                120.49
# 9997                     55.60  39.0     38067.08                124.44
# 9998                     46.61  50.0     43974.49                123.13
# 9999                     46.61  43.0     60575.99                198.45
#
#                                ad_topic_line             city  gender  \
# ...

# %%
sns.barplot(data=df,x='area_income_group',y='clicked_on_ad')
# Out:
# <Axes: xlabel='area_income_group', ylabel='clicked_on_ad'>

# %%
# area_income_Group == 4 이고 gender가 Female인 ad_topic_line에 대한 값 정렬 탑 10
df[(df['area_income_group']==4) & (df['gender']=='Female')]['ad_topic_line'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='ad_topic_line'>

# %%
df['age_group'] = df['age']//10*10

# %%
df
# Out:
#       daily_time_spent_on_site   age  area_income  daily_internet_usage  \
# 0                        62.26  32.0     69481.85                172.83
# 1                        41.73  31.0     61840.26                207.17
# 2                        44.40  30.0     57877.15                172.83
# 3                        59.88  28.0     56180.93                207.17
# 4                        49.21  30.0     54324.73                201.58
# ...                        ...   ...          ...                   ...
# 9995                     41.73  31.0     61840.26                207.17
# 9996                     41.73  28.0     51501.38                120.49
# 9997                     55.60  39.0     38067.08                124.44
# 9998                     46.61  50.0     43974.49                123.13
# 9999                     46.61  43.0     60575.99                198.45
#
#                                ad_topic_line             city  gender  \
# ...

# %%
sns.heatmap(df.groupby(['area_income_group', 'age_group'])['clicked_on_ad'].mean().unstack(),annot=True,fmt='0.2f')
# Out:
# c:\Users\hyundong\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# <Axes: xlabel='age_group', ylabel='area_income_group'>
