# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Global_Life_Expectancy_1960-2022.csv')

# %%
data.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Life expectancy at birth, total (years)
# 1  Afghanistan          AFG  Life expectancy at birth, total (years)
# 2       Angola          AGO  Life expectancy at birth, total (years)
# 3      Albania          ALB  Life expectancy at birth, total (years)
# 4      Andorra          AND  Life expectancy at birth, total (years)
#
#    Indicator Code                     Region          IncomeGroup    1960  \
# 0  SP.DYN.LE00.IN  Latin America & Caribbean          High income  64.152
# 1  SP.DYN.LE00.IN                 South Asia           Low income  32.535
# 2  SP.DYN.LE00.IN         Sub-Saharan Africa  Lower middle income  38.211
# 3  SP.DYN.LE00.IN      Europe & Central Asia  Upper middle income  54.439
# 4  SP.DYN.LE00.IN      Europe & Central Asia          High income     NaN
#
#      1961    1962    1963  ...    2014    2015    2016    2017    2018  \
# 0  64.537  64.752  65.132  ...  75.601  75.683  75.617  75.903  76.072
# 1  33.068  33.547  34.016  ...  62.545  62.659  63.136  63.016  63.081
# 2  37.267  37.539  37.824  ...  60.040  60.655  61.092  61.680  62.144
# 3  55.634  56.671  57.844  ...  78.407  78.644  78.860  79.047  79.184
# 4     NaN     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
#
#      2019    2020    2021    2022  \
# 0  76.248  75.723  74.626  74.992
# 1  63.565  62.575  61.982  62.879
# 2  62.448  62.261  61.643  61.929
# 3  79.282  76.989  76.463  76.833
# 4     NaN     NaN     NaN     NaN
#
#                                         SpecialNotes
# 0                                                NaN
# 1  The reporting period for national accounts dat...
# 2  The World Bank systematically assesses the app...
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 70 columns]

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        'Region', 'IncomeGroup', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', 'SpecialNotes'],
#       dtype='object')

# %%
data_columns = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
       'Region', 'IncomeGroup', 'year', 'life_expectation']

# %%
df = pd.melt(data, id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', 'Region', 'IncomeGroup', 'SpecialNotes'],
                  var_name='year', value_name='life_expectation')

# 연도 데이터 필터링
df = df[df['year'].apply(lambda x: x.isdigit())]

df
# Out:
#        Country Name Country Code                           Indicator Name  \
# 0             Aruba          ABW  Life expectancy at birth, total (years)
# 1       Afghanistan          AFG  Life expectancy at birth, total (years)
# 2            Angola          AGO  Life expectancy at birth, total (years)
# 3           Albania          ALB  Life expectancy at birth, total (years)
# 4           Andorra          AND  Life expectancy at birth, total (years)
# ...             ...          ...                                      ...
# 13666        Kosovo          XKX  Life expectancy at birth, total (years)
# 13667   Yemen, Rep.          YEM  Life expectancy at birth, total (years)
# 13668  South Africa          ZAF  Life expectancy at birth, total (years)
# 13669        Zambia          ZMB  Life expectancy at birth, total (years)
# 13670      Zimbabwe          ZWE  Life expectancy at birth, total (years)
#
#        Indicator Code                      Region          IncomeGroup  \
# 0      SP.DYN.LE00.IN   Latin America & Caribbean          High income
# 1      SP.DYN.LE00.IN                  South Asia           Low income
# 2      SP.DYN.LE00.IN          Sub-Saharan Africa  Lower middle income
# 3      SP.DYN.LE00.IN       Europe & Central Asia  Upper middle income
# 4      SP.DYN.LE00.IN       Europe & Central Asia          High income
# ...               ...                         ...                  ...
# 13666  SP.DYN.LE00.IN       Europe & Central Asia  Upper middle income
# 13667  SP.DYN.LE00.IN  Middle East & North Africa           Low income
# 13668  SP.DYN.LE00.IN          Sub-Saharan Africa  Upper middle income
# 13669  SP.DYN.LE00.IN          Sub-Saharan Africa  Lower middle income
# 13670  SP.DYN.LE00.IN          Sub-Saharan Africa  Lower middle income
#
#                                             SpecialNotes  year  \
# 0                                                    NaN  1960
# 1      The reporting period for national accounts dat...  1960
# 2      The World Bank systematically assesses the app...  1960
# 3                                                    NaN  1960
# 4                                                    NaN  1960
# ...                                                  ...   ...
# 13666                                                NaN  2022
# 13667  The World Bank systematically assesses the app...  2022
# 13668  Fiscal year end: March 31; reporting period fo...  2022
# 13669  National accounts data were rebased to reflect...  2022
# 13670  National Accounts data are reported in Zimbabw...  2022
#
#        life_expectation
# 0                64.152
# 1                32.535
# 2                38.211
# 3                54.439
# 4                   NaN
# ...                 ...
# 13666            79.524
# 13667            63.720
# 13668            61.480
# 13669            61.803
# 13670            59.391
#
# [13671 rows x 9 columns]

# %%
df.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis=1, inplace=True)

# %%
# 시간 순으로 데이터 정렬
df = df.sort_values(by=['Country Name', 'year'])

# 나라별로 그룹화하여 슬라이딩 윈도우 적용
# window_size = 3  # 슬라이딩 윈도우 크기
# df['rolling_mean'] = df.groupby('Country Name')['life_expectation'].rolling(window=window_size).mean().reset_index(0,drop=True)

# 결과 출력
df
# Out:
#       Country Name              Region          IncomeGroup  \
# 1      Afghanistan          South Asia           Low income
# 218    Afghanistan          South Asia           Low income
# 435    Afghanistan          South Asia           Low income
# 652    Afghanistan          South Asia           Low income
# 869    Afghanistan          South Asia           Low income
# ...            ...                 ...                  ...
# 12802     Zimbabwe  Sub-Saharan Africa  Lower middle income
# 13019     Zimbabwe  Sub-Saharan Africa  Lower middle income
# 13236     Zimbabwe  Sub-Saharan Africa  Lower middle income
# 13453     Zimbabwe  Sub-Saharan Africa  Lower middle income
# 13670     Zimbabwe  Sub-Saharan Africa  Lower middle income
#
#                                             SpecialNotes  year  \
# 1      The reporting period for national accounts dat...  1960
# 218    The reporting period for national accounts dat...  1961
# 435    The reporting period for national accounts dat...  1962
# 652    The reporting period for national accounts dat...  1963
# 869    The reporting period for national accounts dat...  1964
# ...                                                  ...   ...
# 12802  National Accounts data are reported in Zimbabw...  2018
# 13019  National Accounts data are reported in Zimbabw...  2019
# 13236  National Accounts data are reported in Zimbabw...  2020
# 13453  National Accounts data are reported in Zimbabw...  2021
# 13670  National Accounts data are reported in Zimbabw...  2022
#
#        life_expectation
# 1                32.535
# 218              33.068
# 435              33.547
# 652              34.016
# 869              34.494
# ...                 ...
# 12802            61.414
# 13019            61.292
# 13236            61.124
# 13453            59.253
# 13670            59.391
#
# [13671 rows x 6 columns]

# %%
# 라벨 인코딩을 위한 라이브러리 불러오기
from sklearn.preprocessing import LabelEncoder

# 라벨 인코더 초기화
label_encoder = LabelEncoder()

# 각 열에 대해 라벨 인코딩 적용
df['Country Name'] = label_encoder.fit_transform(df['Country Name'])
df['Region'] = label_encoder.fit_transform(df['Region'])
df['IncomeGroup'] = label_encoder.fit_transform(df['IncomeGroup'])

# 결과 출력
df
# Out:
#        Country Name  Region  IncomeGroup  \
# 1                 0       5            1
# 218               0       5            1
# 435               0       5            1
# 652               0       5            1
# 869               0       5            1
# ...             ...     ...          ...
# 12802           216       6            2
# 13019           216       6            2
# 13236           216       6            2
# 13453           216       6            2
# 13670           216       6            2
#
#                                             SpecialNotes  year  \
# 1      The reporting period for national accounts dat...  1960
# 218    The reporting period for national accounts dat...  1961
# 435    The reporting period for national accounts dat...  1962
# 652    The reporting period for national accounts dat...  1963
# 869    The reporting period for national accounts dat...  1964
# ...                                                  ...   ...
# 12802  National Accounts data are reported in Zimbabw...  2018
# 13019  National Accounts data are reported in Zimbabw...  2019
# 13236  National Accounts data are reported in Zimbabw...  2020
# 13453  National Accounts data are reported in Zimbabw...  2021
# 13670  National Accounts data are reported in Zimbabw...  2022
#
#        life_expectation
# 1                32.535
# 218              33.068
# 435              33.547
# 652              34.016
# 869              34.494
# ...                 ...
# 12802            61.414
# 13019            61.292
# 13236            61.124
# 13453            59.253
# 13670            59.391
#
# [13671 rows x 6 columns]

# %%
df.dropna(inplace=True)

# %%
# Country Name, year를 기준으로 데이터 정렬
df = df.sort_values(by=['Country Name', 'year'])

# Country Name, year을 슬라이딩 윈도우
window_size = 3

X_series = []
X_text = []
y = []

for country in df['Country Name'].unique():
    country_data = df[df['Country Name'] == country]
    for i in range(window_size, len(country_data)):
        X_series.append(country_data.iloc[i-window_size:i].drop(['life_expectation', 'SpecialNotes'], axis=1))
        X_text.append(country_data.iloc[i]['SpecialNotes'])
        y.append(country_data.iloc[i]['life_expectation'])
        
X_series = np.array(X_series, dtype=np.float32)
y = np.array(y, dtype=np.float32)

# %%
# tf_idf
from sklearn.feature_extraction.text import TfidfVectorizer

# tf-idf 벡터화
tfidf = TfidfVectorizer()

# 텍스트 데이터 벡터화
X_text = tfidf.fit_transform(X_text).toarray()

# %%
# test, train 데이터 분리

from sklearn.model_selection import train_test_split

X_series_train, X_series_test, X_text_train, X_text_test, y_train, y_test = train_test_split(X_series, X_text, y, test_size=0.2, random_state=42, shuffle=False)

# %%
# CNN LSTM 모델 생성

from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Dense, Flatten
from keras.layers import Input


#CNN LSTM 모델 생성
input1 = Input(shape=(X_series_train.shape[1], X_series_train.shape[2]))
x = Conv1D(filters=64, kernel_size=2, activation='relu')(input1)
x = LSTM(64, activation='relu')(x)

input2 = Input(shape=(X_text_train.shape[1],))
y = Dense(64, activation='relu')(input2)

from keras.layers import concatenate
from keras.models import Model

result = concatenate([x, y])
output = Dense(1)(result)

model = Model(inputs=[input1, input2], outputs=output)

model.compile(optimizer='adam', loss='mse')

# %%
from keras.utils import plot_model

plot_model(model, show_shapes=True)

# %%
history = model.fit([X_series_train, X_text_train], y_train, epochs=100, batch_size=32, validation_data=([X_series_test, X_text_test], y_test))
# Out:
# Epoch 1/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 169.2429 - val_loss: 121.0860
# Epoch 2/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 78.4242 - val_loss: 104.3686
# Epoch 3/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 70.9885 - val_loss: 101.4028
# Epoch 4/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 62.7694 - val_loss: 102.1330
# Epoch 5/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 62.6582 - val_loss: 114.0055
# Epoch 6/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 55.9698 - val_loss: 100.5093
# Epoch 7/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 53.8378 - val_loss: 97.9476
# Epoch 8/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 51.4447 - val_loss: 110.8003
# Epoch 9/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48.3431 - val_loss: 95.8280
# Epoch 10/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 55.4431 - val_loss: 98.7511
# Epoch 11/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49.1565 - val_loss: 97.6854
# Epoch 12/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43.2288 - val_loss: 93.2317
# Epoch 13/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43.2141 - val_loss: 92.8379
# Epoch 14/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.1414 - val_loss: 90.9516
# Epoch 15/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.5195 - val_loss: 92.4884
# Epoch 16/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.9271 - val_loss: 89.9210
# Epoch 17/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.9538 - val_loss: 87.8420
# Epoch 18/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40.4477 - val_loss: 86.0900
# Epoch 19/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.6862 - val_loss: 88.1356
# Epoch 20/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 39.1648 - val_loss: 83.2981
# Epoch 21/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.8287 - val_loss: 103.5989
# Epoch 22/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40.0847 - val_loss: 85.1307
# Epoch 23/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.8691 - val_loss: 89.6093
# Epoch 24/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.3034 - val_loss: 83.1244
# Epoch 25/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.2670 - val_loss: 83.0055
# Epoch 26/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.7438 - val_loss: 90.1214
# Epoch 27/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.5783 - val_loss: 83.3727
# Epoch 28/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.9544 - val_loss: 81.7135
# Epoch 29/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.7741 - val_loss: 83.6442
# Epoch 30/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 39.3180 - val_loss: 84.1824
# Epoch 31/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.2295 - val_loss: 119.0425
# Epoch 32/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.4849 - val_loss: 97.5405
# Epoch 33/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.7648 - val_loss: 102.1709
# Epoch 34/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.1186 - val_loss: 92.7841
# Epoch 35/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.6447 - val_loss: 137.9794
# Epoch 36/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.8717 - val_loss: 99.3513
# Epoch 37/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.1811 - val_loss: 99.5483
# Epoch 38/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.1798 - val_loss: 90.9038
# Epoch 39/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.7878 - val_loss: 99.2596
# Epoch 40/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.9041 - val_loss: 101.2473
# Epoch 41/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.8432 - val_loss: 89.4371
# Epoch 42/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.8332 - val_loss: 95.7995
# Epoch 43/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.4474 - val_loss: 93.4087
# Epoch 44/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.9675 - val_loss: 123.7058
# Epoch 45/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 39.2802 - val_loss: 107.4525
# Epoch 46/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.3436 - val_loss: 91.7068
# Epoch 47/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37.4498 - val_loss: 100.1070
# Epoch 48/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.2555 - val_loss: 86.0177
# Epoch 49/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.0618 - val_loss: 131.7742
# Epoch 50/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.4311 - val_loss: 108.7869
# Epoch 51/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.0924 - val_loss: 99.2559
# Epoch 52/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35.6523 - val_loss: 101.5079
# Epoch 53/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.7379 - val_loss: 106.5915
# Epoch 54/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.6095 - val_loss: 107.2584
# Epoch 55/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.2583 - val_loss: 94.1178
# Epoch 56/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.4638 - val_loss: 105.8311
# Epoch 57/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.1455 - val_loss: 105.1438
# Epoch 58/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.7413 - val_loss: 107.4406
# Epoch 59/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2482 - val_loss: 105.7548
# Epoch 60/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.6652 - val_loss: 94.2802
# Epoch 61/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.7270 - val_loss: 96.4362
# Epoch 62/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.6388 - val_loss: 99.0102
# Epoch 63/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.8156 - val_loss: 95.7571
# Epoch 64/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.8909 - val_loss: 96.2669
# Epoch 65/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.3888 - val_loss: 100.8534
# Epoch 66/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.7092 - val_loss: 95.4620
# Epoch 67/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2516 - val_loss: 98.9558
# Epoch 68/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.9443 - val_loss: 92.0163
# Epoch 69/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.8910 - val_loss: 109.4914
# Epoch 70/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.2979 - val_loss: 126.2622
# Epoch 71/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.0305 - val_loss: 110.5960
# Epoch 72/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.0203 - val_loss: 107.1420
# Epoch 73/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.2912 - val_loss: 110.5803
# Epoch 74/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.3359 - val_loss: 104.3894
# Epoch 75/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.8263 - val_loss: 118.0155
# Epoch 76/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.4339 - val_loss: 99.7896
# Epoch 77/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.3142 - val_loss: 92.8207
# Epoch 78/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.6855 - val_loss: 108.1523
# Epoch 79/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.6187 - val_loss: 112.5429
# Epoch 80/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.9346 - val_loss: 121.7239
# Epoch 81/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.5892 - val_loss: 99.9528
# Epoch 82/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.3024 - val_loss: 122.9097
# Epoch 83/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.6421 - val_loss: 115.2002
# Epoch 84/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.3722 - val_loss: 119.8341
# Epoch 85/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.7386 - val_loss: 107.6795
# Epoch 86/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.4691 - val_loss: 101.8476
# Epoch 87/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.0068 - val_loss: 132.1227
# Epoch 88/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.8157 - val_loss: 112.0470
# Epoch 89/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2133 - val_loss: 88.6931
# Epoch 90/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.9941 - val_loss: 94.8696
# Epoch 91/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.0424 - val_loss: 100.8173
# Epoch 92/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.5373 - val_loss: 104.2129
# Epoch 93/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.2772 - val_loss: 109.0052
# Epoch 94/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.5093 - val_loss: 101.0860
# Epoch 95/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.1167 - val_loss: 108.4409
# Epoch 96/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.1375 - val_loss: 114.6165
# Epoch 97/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.1885 - val_loss: 117.4524
# Epoch 98/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.0674 - val_loss: 115.2668
# Epoch 99/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.9597 - val_loss: 100.8975
# Epoch 100/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.7925 - val_loss: 98.8091

# %%
def plot_loss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc=0)
    
plot_loss(history)

# %%
pred = model.predict([X_series_test, X_text_test])

plt.plot(y_test, label='True')
plt.plot(pred, label='Prediction')
plt.legend()
plt.show()

# 결과 출력
mse = np.mean((y_test - pred)**2)
print('Mean Squared Error:', mse)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error: 247.19286

# %%
#CNN LSTM 모델 생성
input1 = Input(shape=(X_series_train.shape[1], X_series_train.shape[2]))
x = Conv1D(filters=64, kernel_size=2, activation='relu')(input1)
x = LSTM(64, activation='relu')(x)
output = Dense(1)(x)

model = Model(inputs=input1, outputs=output)

model.compile(optimizer='adam', loss='mse')

history = model.fit(X_series_train, y_train, epochs=100, batch_size=32, validation_data=(X_series_test, y_test))

plot_loss(history)
# Out:
# Epoch 1/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 432.8039 - val_loss: 149.8264
# Epoch 2/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 117.2840 - val_loss: 145.3844
# Epoch 3/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 118.5360 - val_loss: 147.1141
# Epoch 4/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 110.5712 - val_loss: 151.5659
# Epoch 5/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 109.8885 - val_loss: 143.9480
# Epoch 6/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 101.0824 - val_loss: 121.7866
# Epoch 7/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 98.1348 - val_loss: 135.5947
# Epoch 8/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 92.5436 - val_loss: 92.2776
# Epoch 9/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 77.1641 - val_loss: 91.5258
# Epoch 10/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 72.2605 - val_loss: 101.6100
# Epoch 11/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 88.4300 - val_loss: 102.7421
# Epoch 12/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 71.9318 - val_loss: 85.0754
# Epoch 13/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 68.9155 - val_loss: 98.7040
# Epoch 14/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.9570 - val_loss: 83.8816
# Epoch 15/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 68.2045 - val_loss: 88.0339
# Epoch 16/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 68.0292 - val_loss: 88.6262
# Epoch 17/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 66.6512 - val_loss: 95.1524
# Epoch 18/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 72.4098 - val_loss: 93.9323
# Epoch 19/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 71.7001 - val_loss: 123.1058
# Epoch 20/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 68.7544 - val_loss: 102.7943
# Epoch 21/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 64.7767 - val_loss: 90.1642
# Epoch 22/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 76.4862 - val_loss: 95.7226
# Epoch 23/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 65.5727 - val_loss: 96.5977
# Epoch 24/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.6548 - val_loss: 93.2866
# Epoch 25/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 64.0929 - val_loss: 96.5523
# Epoch 26/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.6784 - val_loss: 90.8118
# Epoch 27/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.1669 - val_loss: 94.3224
# Epoch 28/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 68.3450 - val_loss: 127.4320
# Epoch 29/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.1346 - val_loss: 97.4187
# Epoch 30/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.1277 - val_loss: 102.4819
# Epoch 31/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 62.9613 - val_loss: 108.8733
# Epoch 32/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.4997 - val_loss: 105.9205
# Epoch 33/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 61.2851 - val_loss: 99.6107
# Epoch 34/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 62.1720 - val_loss: 106.1289
# Epoch 35/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 62.8769 - val_loss: 138.7267
# Epoch 36/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.6627 - val_loss: 97.2705
# Epoch 37/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 70.4114 - val_loss: 119.5664
# Epoch 38/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 65.7096 - val_loss: 102.4313
# Epoch 39/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 64.1573 - val_loss: 110.2065
# Epoch 40/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 64.7787 - val_loss: 101.9962
# Epoch 41/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 62.6257 - val_loss: 100.8860
# Epoch 42/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 66.2030 - val_loss: 130.8005
# Epoch 43/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.2618 - val_loss: 98.5025
# Epoch 44/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 64.3273 - val_loss: 86.3229
# Epoch 45/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 65.5648 - val_loss: 136.4149
# Epoch 46/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.8744 - val_loss: 101.3616
# Epoch 47/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64.1641 - val_loss: 114.6441
# Epoch 48/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 88.0197 - val_loss: 103.0917
# Epoch 49/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 67.5524 - val_loss: 100.3533
# Epoch 50/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 69.2882 - val_loss: 100.3495
# Epoch 51/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 59.0163 - val_loss: 118.5122
# Epoch 52/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 61.8730 - val_loss: 106.2955
# Epoch 53/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 65.2734 - val_loss: 103.9205
# Epoch 54/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 61.5699 - val_loss: 143.7627
# Epoch 55/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 64.2514 - val_loss: 163.7011
# Epoch 56/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 97.4155 - val_loss: 108.3348
# Epoch 57/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 84.9443 - val_loss: 105.7479
# Epoch 58/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 78.9548 - val_loss: 96.6258
# Epoch 59/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 70.9806 - val_loss: 91.6800
# Epoch 60/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.5418 - val_loss: 91.8711
# Epoch 61/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 67.0022 - val_loss: 80.6753
# Epoch 62/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 65.8676 - val_loss: 77.6990
# Epoch 63/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 66.8130 - val_loss: 84.2383
# Epoch 64/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 68.2790 - val_loss: 75.0370
# Epoch 65/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 67.2601 - val_loss: 90.0195
# Epoch 66/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 68.0875 - val_loss: 79.7931
# Epoch 67/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 64.0709 - val_loss: 78.0576
# Epoch 68/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 70.0190 - val_loss: 81.7443
# Epoch 69/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 67.7576 - val_loss: 79.8552
# Epoch 70/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67.0616 - val_loss: 78.4661
# Epoch 71/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 65.8431 - val_loss: 82.6985
# Epoch 72/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 67.0209 - val_loss: 88.8997
# Epoch 73/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 61.2171 - val_loss: 90.0635
# Epoch 74/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 73.3817 - val_loss: 76.7212
# Epoch 75/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 64.1809 - val_loss: 88.3309
# Epoch 76/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 64.7471 - val_loss: 80.2970
# Epoch 77/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 65.3437 - val_loss: 83.0978
# Epoch 78/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 67.7157 - val_loss: 81.1103
# Epoch 79/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 66.7285 - val_loss: 78.0359
# Epoch 80/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 64.8605 - val_loss: 81.7490
# Epoch 81/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 70.2049 - val_loss: 80.3458
# Epoch 82/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 64.1559 - val_loss: 86.8454
# Epoch 83/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 61.5182 - val_loss: 78.9728
# Epoch 84/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 66.5781 - val_loss: 87.9984
# Epoch 85/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 64.6836 - val_loss: 85.9623
# Epoch 86/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 64.4511 - val_loss: 92.1217
# Epoch 87/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 67.7970 - val_loss: 97.2779
# Epoch 88/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 62.9749 - val_loss: 98.2831
# Epoch 89/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 61.8730 - val_loss: 110.6996
# Epoch 90/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 68.2623 - val_loss: 114.6789
# Epoch 91/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 59.9555 - val_loss: 139.8301
# Epoch 92/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 66.0261 - val_loss: 106.3935
# Epoch 93/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 61.9656 - val_loss: 137.6760
# Epoch 94/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 62.8654 - val_loss: 94.5366
# Epoch 95/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 67.8654 - val_loss: 135.7416
# Epoch 96/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 70.8027 - val_loss: 112.1555
# Epoch 97/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 63.3819 - val_loss: 128.1402
# Epoch 98/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 63.4498 - val_loss: 97.3781
# Epoch 99/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 62.8746 - val_loss: 101.0199
# Epoch 100/100
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 67.2313 - val_loss: 112.6611

# %%
plot_model(model, show_shapes=True)

# %%
pred = model.predict(X_series_test)
mse = np.mean(np.square(pred - y_test))
print(mse)


plt.plot(y_test, label='True')
plt.plot(pred, label='Prediction')
plt.legend()
plt.show()
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 204.23363
