# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 데이터를 불러옵니다. 파일 경로는 실제 데이터 파일의 경로에 맞게 수정하세요.
data_train = pd.read_csv('/content/drive/MyDrive/open/train.csv')
data_test = pd.read_csv('/content/drive/MyDrive/open/test.csv')

#test DATA feature만 가진 train DATA
train = data_train[data_test.columns.to_list()+['Y_LABEL','SAMPLE_TRANSFER_DAY']].copy()

# 1. 분석의 목적과 목적에 맞는 변수 확인
# 데이터의 구조와 변수 목록을 살펴봅니다.
print("데이터 정보:")
print(data_train.info())

# 데이터의 처음 몇 개 레코드를 확인하여 변수 및 데이터의 형태를 이해합니다.
print("\n데이터 샘플:")
print(data_train.head())

# 2. 데이터형 확인 및 데이터 오류/누락 여부 확인
# 각 열의 데이터 유형 및 결측치 확인
print("\n데이터 유형 및 결측치:")
print(data_train.dtypes)
print(data_train.isnull().sum())

# 3. 데이터 분포 확인
# 데이터의 기술 통계량을 계산하여 분포를 확인합니다.
print("\n데이터 기술 통계량:")
print(data_train.describe())
# Out:
# 데이터 정보:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14095 entries, 0 to 14094
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   14095 non-null  object
#  1   COMPONENT_ARBITRARY  14095 non-null  object
#  2   ANONYMOUS_1          14095 non-null  float64
#  3   YEAR                 14095 non-null  int64
#  4   SAMPLE_TRANSFER_DAY  14095 non-null  int64
#  5   ANONYMOUS_2          14095 non-null  float64
#  6   AG                   14095 non-null  int64
#  7   AL                   14095 non-null  int64
#  8   B                    14095 non-null  int64
#  9   BA                   14095 non-null  int64
#  10  BE                   14095 non-null  int64
#  11  CA                   14095 non-null  int64
#  12  CD                   12701 non-null  float64
#  13  CO                   14095 non-null  int64
#  14  CR                   14095 non-null  int64
#  15  CU                   14095 non-null  int64
#  16  FH2O                 3890 non-null   float64
#  17  FNOX                 3890 non-null   float64
#  18  FOPTIMETHGLY         3890 non-null   float64
#  19  FOXID                3890 non-null   float64
#  20  FSO4                 3890 non-null   float64
#  21  FTBN                 3890 non-null   float64
#  22  FE                   14095 non-null  int64
#  23  FUEL                 3890 non-null   float64
#  24  H2O                  14095 non-null  float64
#  25  K                    11796 non-null  float64
#  26  LI                   14095 non-null  int64
#  27  MG                   14095 non-null  int64
#  28  MN                   14095 non-null  int64
#  29  MO                   14095 non-null  int64
#  30  NA                   14095 non-null  int64
#  31  NI                   14095 non-null  int64
#  32  P                    14095 non-null  int64
#  33  PB                   14095 non-null  int64
#  34  PQINDEX              14095 non-null  int64
#  35  S                    14095 non-null  int64
#  36  SB                   14095 non-null  int64
#  37  SI                   14095 non-null  int64
#  38  SN                   14095 non-null  int64
#  39  SOOTPERCENTAGE       3890 non-null   float64
#  40  TI                   14095 non-null  int64
#  41  U100                 2316 non-null   float64
#  42  U75                  2316 non-null   float64
#  43  U50                  2316 non-null   float64
#  44  U25                  2316 non-null   float64
#  45  U20                  2316 non-null   float64
#  46  U14                  2118 non-null   float64
#  47  U6                   2118 non-null   float64
#  48  U4                   2118 non-null   float64
#  49  V                    14095 non-null  int64
#  50  V100                 3724 non-null   float64
#  51  V40                  14095 non-null  float64
#  52  ZN                   14095 non-null  int64
#  53  Y_LABEL              14095 non-null  int64
# dtypes: float64(23), int64(29), object(2)
# memory usage: 5.8+ MB
# None
#
# 데이터 샘플:
#             ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  SAMPLE_TRANSFER_DAY  \
# 0  TRAIN_00000          COMPONENT3    -0.996688  2011                    7
# 1  TRAIN_00001          COMPONENT2    -0.997615  2021                   51
# 2  TRAIN_00002          COMPONENT2    -0.990356  2015                    2
# 3  TRAIN_00003          COMPONENT3    -0.956456  2010                    2
# 4  TRAIN_00004          COMPONENT3    -0.979867  2015                    4
#
#    ANONYMOUS_2  AG   AL    B  BA  ...  U25  U20   U14       U6       U4  V  \
# 0    -1.000000   0    3   93   0  ...  NaN  NaN   NaN      NaN      NaN  0
# 1    -0.962963   0    2   19   0  ...  2.0  4.0   6.0    216.0   1454.0  0
# 2    -1.000000   0  110    1   1  ...  0.0  3.0  39.0  11261.0  41081.0  0
# 3    -1.000000   0    8    3   0  ...  NaN  NaN   NaN      NaN      NaN  0
# 4    -1.000000   0    1  157   0  ...  NaN  NaN   NaN      NaN      NaN  0
#
#    V100    V40   ZN  Y_LABEL
# 0   NaN  154.0   75        1
# 1   NaN   44.0  652        0
# 2   NaN   72.6  412        0
# 3   NaN  133.3    7        0
# 4   NaN  133.1  128        0
#
# [5 rows x 54 columns]
#
# 데이터 유형 및 결측치:
# ID                      object
# COMPONENT_ARBITRARY     object
# ANONYMOUS_1            float64
# YEAR                     int64
# SAMPLE_TRANSFER_DAY      int64
# ANONYMOUS_2            float64
# AG                       int64
# AL                       int64
# B                        int64
# BA                       int64
# BE                       int64
# CA                       int64
# CD                     float64
# CO                       int64
# CR                       int64
# CU                       int64
# FH2O                   float64
# FNOX                   float64
# FOPTIMETHGLY           float64
# FOXID                  float64
# FSO4                   float64
# FTBN                   float64
# FE                       int64
# FUEL                   float64
# H2O                    float64
# K                      float64
# LI                       int64
# MG                       int64
# MN                       int64
# MO                       int64
# NA                       int64
# NI                       int64
# P                        int64
# PB                       int64
# PQINDEX                  int64
# S                        int64
# SB                       int64
# SI                       int64
# SN                       int64
# SOOTPERCENTAGE         float64
# TI                       int64
# U100                   float64
# U75                    float64
# U50                    float64
# U25                    float64
# U20                    float64
# U14                    float64
# U6                     float64
# U4                     float64
# V                        int64
# V100                   float64
# V40                    float64
# ZN                       int64
# Y_LABEL                  int64
# dtype: object
# ID                         0
# COMPONENT_ARBITRARY        0
# ANONYMOUS_1                0
# YEAR                       0
# SAMPLE_TRANSFER_DAY        0
# ANONYMOUS_2                0
# AG                         0
# AL                         0
# B                          0
# BA                         0
# BE                         0
# CA                         0
# CD                      1394
# CO                         0
# CR                         0
# CU                         0
# FH2O                   10205
# FNOX                   10205
# FOPTIMETHGLY           10205
# FOXID                  10205
# FSO4                   10205
# FTBN                   10205
# FE                         0
# FUEL                   10205
# H2O                        0
# K                       2299
# LI                         0
# MG                         0
# MN                         0
# MO                         0
# NA                         0
# NI                         0
# P                          0
# PB                         0
# PQINDEX                    0
# S                          0
# SB                         0
# SI                         0
# SN                         0
# SOOTPERCENTAGE         10205
# TI                         0
# U100                   11779
# U75                    11779
# U50                    11779
# U25                    11779
# U20                    11779
# U14                    11977
# U6                     11977
# U4                     11977
# V                          0
# V100                   10371
# V40                        0
# ZN                         0
# Y_LABEL                    0
# dtype: int64
#
# 데이터 기술 통계량:
#         ANONYMOUS_1          YEAR  SAMPLE_TRANSFER_DAY   ANONYMOUS_2  \
# count  14095.000000  14095.000000         14095.000000  14095.000000
# mean      -0.985373   2013.652501             7.600568     -0.960335
# std        0.028735      3.964758            11.681628      0.116406
# min       -1.000000   2007.000000             0.000000     -1.000000
# 25%       -0.995536   2010.000000             3.000000     -1.000000
# 50%       -0.991637   2014.000000             5.000000     -1.000000
# 75%       -0.980937   2017.000000             8.000000     -0.955556
# max        1.000000   2022.000000           368.000000      1.000000
#
#                  AG            AL             B            BA            BE  \
# count  14095.000000  14095.000000  14095.000000  14095.000000  14095.000000
# mean       0.025825     12.707698     64.026179      0.692799      0.006314
# std        0.171926     86.968000    102.876871      2.905491      0.152189
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      3.000000      0.000000      0.000000
# 50%        0.000000      2.000000     11.000000      0.000000      0.000000
# 75%        0.000000      4.000000    110.000000      0.000000      0.000000
# max        3.000000   4630.000000   2051.000000    216.000000      9.000000
#
#                  CA  ...          U25          U20           U14  \
# count  14095.000000  ...  2316.000000  2316.000000   2118.000000
# mean    1366.757574  ...    29.870898    56.063472    239.938149
# std     1481.924727  ...    97.459625   184.332678    685.053457
# min        0.000000  ...     0.000000     0.000000      0.000000
# 25%       48.000000  ...     3.000000     5.000000     22.000000
# 50%      198.000000  ...     7.000000    13.000000     57.000000
# 75%     2975.000000  ...    23.000000    39.250000    189.000000
# max     6609.000000  ...  1651.000000  2932.000000  11296.000000
#
#                   U6             U4             V         V100           V40  \
# count    2118.000000    2118.000000  14095.000000  3724.000000  14095.000000
# mean     5488.693107   19415.597262      0.050656    13.576230    109.355815
# std     15474.146283   40145.311444      0.475438     1.073718     49.612379
# min        15.000000     154.000000      0.000000     5.200000      2.900000
# 25%       636.750000    5409.250000      0.000000    12.900000     71.800000
# 50%      1753.000000   12691.500000      0.000000    13.500000    111.300000
# 75%      5517.750000   24535.750000      0.000000    14.200000    137.200000
# max    412627.000000  844421.000000     17.000000    29.900000   2840.500000
#
#                  ZN       Y_LABEL
# count  14095.000000  14095.000000
# mean     588.646825      0.214544
# std      531.743393      0.410520
# min        0.000000      0.000000
# 25%       37.000000      0.000000
# 50%      520.000000      0.000000
# 75%     1119.000000      0.000000
# max     2132.000000      1.000000
#
# [8 rows x 52 columns]

# %% [markdown]
# ### 결측치

# %%
columns_with_missing_values_52 = data_train.columns[data_train.isna().any()].tolist()
columns_with_missing_values_18 = train.columns[train.isna().any()].tolist()


# 출력
print("결측치를 가지고 있는 열:", columns_with_missing_values_52)
print("결측치를 가지고 있는 열:", columns_with_missing_values_18)
# Out:
# 결측치를 가지고 있는 열: ['CD', 'FH2O', 'FNOX', 'FOPTIMETHGLY', 'FOXID', 'FSO4', 'FTBN', 'FUEL', 'K', 'SOOTPERCENTAGE', 'U100', 'U75', 'U50', 'U25', 'U20', 'U14', 'U6', 'U4', 'V100']
# 결측치를 가지고 있는 열: []

# %%
# 결측치가 있는 변수 및 결측률 파악 - 결측률이 0.7이상인 column 17개 제거 ?

mis_val = data_train.isnull().sum()
mis_val_bool = mis_val >= 1
mis_val_df = pd.concat([mis_val, mis_val_bool], axis = 1)
mis_val_df = mis_val_df.rename(columns = {0 : 'mis_val', 1 : 'mis_val_bool'})

mis_val_data = mis_val_df.loc[mis_val_df['mis_val_bool'] == True, :]
mis_val_data['ratio'] = mis_val_data['mis_val'] / 14095
mis_val_data_sorted = mis_val_data.sort_values(by='ratio', ascending=True)
mis_val_data_sorted
# Out:
# <ipython-input-16-310b3d738ff5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis_val_data['ratio'] = mis_val_data['mis_val'] / 14095
#                 mis_val  mis_val_bool     ratio
# CD                 1394          True  0.098900
# K                  2299          True  0.163107
# FUEL              10205          True  0.724016
# FTBN              10205          True  0.724016
# FSO4              10205          True  0.724016
# SOOTPERCENTAGE    10205          True  0.724016
# FOPTIMETHGLY      10205          True  0.724016
# FNOX              10205          True  0.724016
# FH2O              10205          True  0.724016
# FOXID             10205          True  0.724016
# V100              10371          True  0.735793
# U100              11779          True  0.835686
# U75               11779          True  0.835686
# U50               11779          True  0.835686
# U25               11779          True  0.835686
# U20               11779          True  0.835686
# U4                11977          True  0.849734
# U14               11977          True  0.849734
# U6                11977          True  0.849734

# %%
# 결측률이 20% 이상인 변수들 제거

notnull_columns = data_train.loc[:, data_train.notnull().sum(axis = 0) == 14095].columns
notnull_columns = notnull_columns[1 :]
notnull_columns = list(notnull_columns)

select_columns = notnull_columns[: 32] + ['K', 'CD'] + notnull_columns[32 :]
data_train2 = data_train.loc[:, select_columns]
print(data_train2.shape)
print(data_train2.columns)
# Out:
# (14095, 36)
# Index(['COMPONENT_ARBITRARY', 'ANONYMOUS_1', 'YEAR', 'SAMPLE_TRANSFER_DAY',
#        'ANONYMOUS_2', 'AG', 'AL', 'B', 'BA', 'BE', 'CA', 'CO', 'CR', 'CU',
#        'FE', 'H2O', 'LI', 'MG', 'MN', 'MO', 'NA', 'NI', 'P', 'PB', 'PQINDEX',
#        'S', 'SB', 'SI', 'SN', 'TI', 'V', 'V40', 'K', 'CD', 'ZN', 'Y_LABEL'],
#       dtype='object')

# %% [markdown]
# ### 변수 별 상관분석

# %%
# |0.7|>corelation 인경우 높은 상관관계라고 판단.  -> test data에서 drop할 column은 없다 ?
t = train.copy()
corr = t.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <ipython-input-18-73885dae9c49>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = t.corr()
# <style type="text/css">
# #T_d8681_row0_col0, #T_d8681_row1_col1, #T_d8681_row2_col2, #T_d8681_row3_col3, #T_d8681_row4_col4, #T_d8681_row5_col5, #T_d8681_row6_col6, #T_d8681_row7_col7, #T_d8681_row8_col8, #T_d8681_row9_col9, #T_d8681_row10_col10, #T_d8681_row11_col11, #T_d8681_row12_col12, #T_d8681_row13_col13, #T_d8681_row14_col14, #T_d8681_row15_col15, #T_d8681_row16_col16, #T_d8681_row17_col17, #T_d8681_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col1, #T_d8681_row5_col4, #T_d8681_row13_col6, #T_d8681_row15_col11 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col2, #T_d8681_row3_col10, #T_d8681_row5_col1, #T_d8681_row7_col18, #T_d8681_row14_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col3, #T_d8681_row1_col12, #T_d8681_row6_col18, #T_d8681_row9_col18 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col4, #T_d8681_row0_col5, #T_d8681_row2_col14, #T_d8681_row8_col0, #T_d8681_row10_col13, #T_d8681_row11_col10, #T_d8681_row17_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col6, #T_d8681_row2_col0, #T_d8681_row2_col3, #T_d8681_row8_col4, #T_d8681_row10_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col7, #T_d8681_row6_col14, #T_d8681_row17_col3, #T_d8681_row18_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col8, #T_d8681_row5_col0, #T_d8681_row10_col0, #T_d8681_row11_col0, #T_d8681_row16_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col9, #T_d8681_row1_col8, #T_d8681_row7_col0, #T_d8681_row9_col10, #T_d8681_row10_col1, #T_d8681_row10_col5, #T_d8681_row10_col14, #T_d8681_row12_col0, #T_d8681_row13_col0, #T_d8681_row14_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col10, #T_d8681_row1_col13, #T_d8681_row3_col13, #T_d8681_row8_col18, #T_d8681_row10_col7, #T_d8681_row10_col12, #T_d8681_row11_col8, #T_d8681_row18_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col11, #T_d8681_row12_col1, #T_d8681_row15_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col12, #T_d8681_row15_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col13, #T_d8681_row2_col10, #T_d8681_row4_col1, #T_d8681_row5_col10, #T_d8681_row8_col10, #T_d8681_row11_col1, #T_d8681_row14_col8, #T_d8681_row14_col10, #T_d8681_row15_col1, #T_d8681_row15_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col14, #T_d8681_row10_col4, #T_d8681_row18_col4, #T_d8681_row18_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col15, #T_d8681_row4_col13, #T_d8681_row11_col14, #T_d8681_row13_col17 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_d8681_row0_col16, #T_d8681_row4_col16, #T_d8681_row15_col17, #T_d8681_row18_col16 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d8681_row0_col17, #T_d8681_row18_col17 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d8681_row0_col18, #T_d8681_row2_col4, #T_d8681_row2_col5, #T_d8681_row2_col9, #T_d8681_row3_col14, #T_d8681_row18_col5, #T_d8681_row18_col14 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col0, #T_d8681_row2_col12, #T_d8681_row12_col3, #T_d8681_row18_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col2, #T_d8681_row3_col7, #T_d8681_row6_col3, #T_d8681_row16_col6, #T_d8681_row17_col16 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col3, #T_d8681_row1_col4, #T_d8681_row1_col6, #T_d8681_row1_col10, #T_d8681_row1_col18, #T_d8681_row6_col1, #T_d8681_row10_col9, #T_d8681_row15_col2, #T_d8681_row15_col16, #T_d8681_row16_col5, #T_d8681_row16_col7, #T_d8681_row16_col8, #T_d8681_row16_col9, #T_d8681_row16_col11, #T_d8681_row16_col12, #T_d8681_row16_col13, #T_d8681_row16_col14, #T_d8681_row16_col15, #T_d8681_row16_col17, #T_d8681_row18_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col5, #T_d8681_row1_col11, #T_d8681_row5_col2, #T_d8681_row6_col2, #T_d8681_row7_col2, #T_d8681_row8_col2, #T_d8681_row10_col8, #T_d8681_row11_col2, #T_d8681_row16_col0, #T_d8681_row18_col8 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col7, #T_d8681_row4_col10, #T_d8681_row5_col18, #T_d8681_row13_col18, #T_d8681_row14_col18, #T_d8681_row17_col18, #T_d8681_row18_col10 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col9, #T_d8681_row3_col1, #T_d8681_row17_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col14, #T_d8681_row2_col8, #T_d8681_row3_col8, #T_d8681_row4_col2, #T_d8681_row6_col0, #T_d8681_row7_col10, #T_d8681_row10_col11, #T_d8681_row13_col2, #T_d8681_row17_col2, #T_d8681_row18_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d8681_row1_col15, #T_d8681_row5_col16, #T_d8681_row14_col16 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d8681_row1_col16 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_d8681_row1_col17, #T_d8681_row10_col3, #T_d8681_row13_col1, #T_d8681_row15_col3, #T_d8681_row15_col5, #T_d8681_row18_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_d8681_row2_col6, #T_d8681_row3_col11, #T_d8681_row5_col3, #T_d8681_row8_col6, #T_d8681_row13_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col7, #T_d8681_row8_col1, #T_d8681_row9_col3, #T_d8681_row15_col14 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col11, #T_d8681_row3_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col13, #T_d8681_row17_col1, #T_d8681_row18_col13 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col15, #T_d8681_row9_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_d8681_row2_col16 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_d8681_row2_col17, #T_d8681_row6_col13, #T_d8681_row9_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d8681_row2_col18, #T_d8681_row4_col8, #T_d8681_row4_col18, #T_d8681_row8_col5, #T_d8681_row9_col1, #T_d8681_row10_col18 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col0, #T_d8681_row12_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col2, #T_d8681_row10_col2, #T_d8681_row14_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col4, #T_d8681_row3_col5, #T_d8681_row13_col10, #T_d8681_row15_col0, #T_d8681_row16_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col6, #T_d8681_row5_col6, #T_d8681_row17_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col12, #T_d8681_row17_col5, #T_d8681_row18_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col15, #T_d8681_row9_col6, #T_d8681_row12_col13, #T_d8681_row18_col15 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_d8681_row3_col16, #T_d8681_row14_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_d8681_row3_col17 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_d8681_row3_col18 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d8681_row4_col0, #T_d8681_row9_col0, #T_d8681_row18_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d8681_row4_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_d8681_row4_col5, #T_d8681_row8_col13, #T_d8681_row12_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_d8681_row4_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_d8681_row4_col7 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_d8681_row4_col9, #T_d8681_row11_col12, #T_d8681_row12_col17, #T_d8681_row13_col11 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_d8681_row4_col11 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_d8681_row4_col12, #T_d8681_row10_col15, #T_d8681_row13_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_d8681_row4_col14 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_d8681_row4_col15 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_d8681_row4_col17, #T_d8681_row12_col

# %% [markdown]
# ### IQR
# Wilcoxon 순위합 검정을 통해 [이상 집단이 정상 집단보다 큰 값을 가진다]라는 귀무가설에 대한 비모수 검정을 실시했습니다.
#
# p-value ≤ 유의수준 (예: 0.05): 귀무 가설을 기각하고 대립 가설을 채택합니다. 이는 표본 간의 차이가 통계적으로 유의미하다는 것을 의미합니다.

# %%
from scipy.stats import ranksums

def IQR_outlier(data) :
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)

    return pd.concat([lower_bound, upper_bound], axis = 1).T

# 정상 범위와 이상 범위의 데이터 간 윌콕슨 순위합 검정 실시

ranksum_p = []
variable_17 = ['SAMPLE_TRANSFER_DAY', 'AL', 'B', 'BA', 'BE', 'CA', 'CD', 'K', 'LI', 'MG', 'NA', 'P', 'PB', 'S', 'SB', 'SI', 'SN']

# alternative = 'greater'을 걸어줘서 한쪽 검정으로 실시
# scipy 1.8.1 버전 이상이어야 ranksums의 옵션인 alternative(한쪽 검정) 사용 가능
for v in variable_17 :
  temp = ranksums(data_train.loc[(data_train['Y_LABEL'] == 1) & (data_train[v].notnull()), v],
                  data_train.loc[(data_train['Y_LABEL'] == 0) & (data_train[v].notnull()), v],
                  alternative = 'greater').pvalue
  ranksum_p.append(temp)

Wilcoxon_var_table = pd.DataFrame({'variable' : variable_17,
                                   'p_value' : ranksum_p,
                                   'p_value_round' : np.round(ranksum_p, 4)})
Wilcoxon_var_table.sort_values('p_value')
# Out:
#                variable        p_value  p_value_round
# 15                   SI   0.000000e+00         0.0000
# 13                    S  1.970075e-120         0.0000
# 7                     K   1.599942e-50         0.0000
# 10                   NA   5.842989e-36         0.0000
# 8                    LI   2.692208e-09         0.0000
# 1                    AL   2.754589e-07         0.0000
# 14                   SB   8.675096e-05         0.0001
# 16                   SN   3.476822e-04         0.0003
# 3                    BA   2.889683e-02         0.0289
# 6                    CD   3.676709e-01         0.3677
# 4                    BE   4.427969e-01         0.4428
# 12                   PB   5.429325e-01         0.5429
# 2                     B   5.637156e-01         0.5637
# 0   SAMPLE_TRANSFER_DAY   6.505735e-01         0.6506
# 9                    MG   7.765353e-01         0.7765
# 11                    P   9.432950e-01         0.9433
# 5                    CA   9.995568e-01         0.9996

# %%
# P_value가 0.05 이하인 변수만 추출
Wilcoxon_var_table.loc[Wilcoxon_var_table['p_value'] <= 0.05, :].sort_values('p_value')
# Out:
#    variable        p_value  p_value_round
# 15       SI   0.000000e+00         0.0000
# 13        S  1.970075e-120         0.0000
# 7         K   1.599942e-50         0.0000
# 10       NA   5.842989e-36         0.0000
# 8        LI   2.692208e-09         0.0000
# 1        AL   2.754589e-07         0.0000
# 14       SB   8.675096e-05         0.0001
# 16       SN   3.476822e-04         0.0003
# 3        BA   2.889683e-02         0.0289

# %% [markdown]
# ### 불량률

# %%
# 각 변수에 대해 '정상 범위 데이터 개수', '이상 범위 데이터 개수', '전체 데이터 합계',
#               '정상 범위 데이터의 불량 개수', '이상 범위 데이터의 불량 개수', '불량 합계',
#               '정상 범위 데이터의 불량률', '이상 범위 데이터의 불량률'
# 에 대한 Table 생성

variable_7 = ['AL', 'BA', 'K', 'S', 'SB', 'SI', 'SN']

outlier_table = pd.DataFrame(np.zeros([8, len(variable_7)]), columns = variable_7,
                             index = ['정상 범위 데이터 개수', '이상 범위 데이터 개수', '전체 데이터 합계',
                                      '정상 범위 데이터의 불량 개수', '이상 범위 데이터의 불량 개수', '불량 합계',
                                      '정상 범위 데이터의 불량률', '이상 범위 데이터의 불량률'])

for v in variable_7 :
  temp1 = data_train2.loc[(IQR_outlier(data_train2).loc[0, v] <= data_train2[v]) &
                        (data_train2[v] <= IQR_outlier(data_train2).loc[1, v]), :]
  temp2 = data_train2.loc[(IQR_outlier(data_train2).loc[0, v] > data_train2[v]) | (data_train2[v] > IQR_outlier(data_train2).loc[1, v]), :]

  outlier_table.at['정상 범위 데이터 개수', v] = temp1.shape[0]
  outlier_table.at['이상 범위 데이터 개수', v] = temp2.shape[0]
  outlier_table.at['전체 데이터 합계', v] = temp1.shape[0] + temp2.shape[0]

  temp3 = temp1.loc[data_train2['Y_LABEL'] == 1, :]
  temp4 = temp2.loc[data_train2['Y_LABEL'] == 1, :]
  outlier_table.at['정상 범위 데이터의 불량 개수', v] = temp3.shape[0]
  outlier_table.at['이상 범위 데이터의 불량 개수', v] = temp4.shape[0]
  outlier_table.at['불량 합계', v] = temp3.shape[0] + temp4.shape[0]

  if temp1.shape[0] == 0 :
    temp5 = 0
  else :
    temp5 = np.round(temp3.shape[0] / temp1.shape[0] * 100, 3)
  outlier_table.at['정상 범위 데이터의 불량률', v] = temp5

  if temp2.shape[0] == 0 :
    temp6 = 0
  else :
    temp6 = np.round(temp4.shape[0] / temp2.shape[0] * 100, 3)
  outlier_table.at['이상 범위 데이터의 불량률', v] = temp6

outlier_table = outlier_table.T
outlier_table.nlargest(len(variable_17), columns = ['이상 범위 데이터의 불량률'])
# Out:
# <ipython-input-28-6733e88c8a8a>:4: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = data.quantile(0.25)
# <ipython-input-28-6733e88c8a8a>:5: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = data.quantile(0.75)
#     정상 범위 데이터 개수  이상 범위 데이터 개수  전체 데이터 합계  정상 범위 데이터의 불량 개수  이상 범위 데이터의 불량 개수  \
# S        14088.0           7.0    14095.0            3017.0               7.0
# SI       12246.0        1849.0    14095.0            1937.0            1087.0
# K        10738.0        1058.0    11796.0            1879.0             468.0
# AL       12651.0        1444.0    14095.0            2626.0             398.0
# SB       11128.0        2967.0    14095.0            2287.0             737.0
# SN       12778.0        1317.0    14095.0            2702.0             322.0
# BA       10780.0        3315.0    14095.0            2258.0             766.0
#
#      불량 합계  정상 범위 데이터의 불량률  이상 범위 데이터의 불량률
# S   3024.0          21.415         100.000
# SI  3024.0          15.817          58.789
# K   2347.0          17.499          44.234
# AL  3024.0          20.757          27.562
# SB  3024.0          20.552          24.840
# SN  3024.0          21.146          24.450
# BA  3024.0          20.946          23.107

# %% [markdown]
# ###18개 데이터 개별 통계 지표 및 속성값 시각화

# %%
for i in range(2,len(train.columns)):
  # 데이터의 개별 속성값 관찰
  attribute_name = train.columns[i]

  # 적절한 요약 통계 지표를 계산합니다.
  mean_value = train[attribute_name].mean()
  median_value = train[attribute_name].median()
  variance_value = train[attribute_name].var()

  print("\n{}의 요약 통계:".format(attribute_name))
  print("평균: {:.2f}".format(mean_value))
  print("중앙값: {:.2f}".format(median_value))
  print("분산: {:.2f}".format(variance_value))

  # 시각화를 사용하여 데이터의 개별 속성값을 관찰
  plt.figure(figsize=(12, 6))
  plt.title("{}의 분포".format(attribute_name))
  plt.xlabel("값")
  plt.ylabel("빈도")
  data_train[attribute_name].hist(bins=30)
  plt.show()

# %% [markdown]
# ###상관분석

# %%
data_train.columns

# %%
# 종속 변수(y_label)와 각 독립 변수 간의 상관 계수 계산
correlation_matrix = data_train.corr()

# 상관 계수 행렬에서 종속 변수와의 상관 계수만 추출
y_label_correlations_52 = correlation_matrix['Y_LABEL']

# 종속 변수와의 상관 계수를 내림차순으로 정렬하여 출력
sorted_correlations_52 = y_label_correlations_52.abs().sort_values(ascending=False)
print("종속 변수(y_label)와의 상관 계수:")
print(sorted_correlations_52)

# 상관 계수를 시각화하여 종속 변수에 미치는 영향 확인
plt.figure(figsize=(12, 6))
sns.barplot(x=sorted_correlations_52.index, y=sorted_correlations_52)
plt.title("독립 변수와 종속 변수(y_label) 간의 상관 계수")
plt.xlabel("독립 변수")
plt.ylabel("상관 계수")
plt.xticks(rotation=90)
plt.show()

# %%
# 종속 변수(y_label)와 각 독립 변수 간의 상관 계수 계산
correlation_matrix = train.corr()

# 상관 계수 행렬에서 종속 변수와의 상관 계수만 추출
y_label_correlations_18 = correlation_matrix['Y_LABEL']

# 종속 변수와의 상관 계수를 내림차순으로 정렬하여 출력
sorted_correlations_18 = y_label_correlations_18.abs().sort_values(ascending=False)
print("종속 변수(y_label)와의 상관 계수:")
print(sorted_correlations)

# 상관 계수를 시각화하여 종속 변수에 미치는 영향 확인
plt.figure(figsize=(12, 6))
sns.barplot(x=sorted_correlations_18.index, y=sorted_correlations_18)
plt.title("독립 변수와 종속 변수(y_label) 간의 상관 계수")
plt.xlabel("독립 변수")
plt.ylabel("상관 계수")
plt.xticks(rotation=90)
plt.show()

# %%
#test DATA feature만 가진 train DATA
train_yo = train[['AG',
       'CO', 'CR', 'CU', 'FE', 'H2O', 'MN', 'MO', 'NI', 'PQINDEX', 'TI', 'V',
       'V40', 'ZN']].copy()

all_nan_or_zero_rows = train_yo[(train_yo.isna() | (train == 0)).all(axis=1)]
all_nan_or_zero_rows
