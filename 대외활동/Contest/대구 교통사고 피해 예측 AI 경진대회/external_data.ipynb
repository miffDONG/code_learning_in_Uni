# %%
import pandas as pd

df = pd.read_csv('./train.csv')

# %%
light_df = pd.read_csv('F:\경진대회\Dacon\대구 교통사고 피해 예측 AI 경진대회\open\external_open\대구 보안등 정보.csv', encoding='cp949')[['설치개수', '소재지지번주소']]

location_pattern = r'(\S+) (\S+) (\S+) (\S+)'

light_df[['도시', '구', '동', '번지']] = light_df['소재지지번주소'].str.extract(location_pattern)
light_df = light_df.drop(columns=['소재지지번주소', '번지'])

light_df = light_df.groupby(['도시', '구', '동']).sum().reset_index()
light_df.reset_index(inplace=True, drop=True)

train_df = pd.merge(df, light_df, how='left', on=['도시', '구', '동'])
# Out:
# C:\Users\hyundong\AppData\Local\Temp\ipykernel_24508\3106065506.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   light_df = pd.read_csv('F:\경진대회\Dacon\대구 교통사고 피해 예측 AI 경진대회\open\external_open\대구 보안등 정보.csv', encoding='cp949')[['설치개수', '소재지지번주소']]

# %%
group_area = {
    '서구': {
        '상중이동': [6.69,['상리동', '중리동', '이현동']],
        '원대동': [0.62,['원대동1가', '원대동2가', '원대동3가']]
    },
    '수성구': {
        '고산동1동': [8.79,['신매동', '욱수동']],
        '고산2동': [24.39,['시지동', '노변동', '삼덕동', '연호동', '이천동', '고모동', '가천동', '대흥동']],
        '고산3동': [5.01,['매호동', '성동', '사월동']],
        '수성2,3가동': [0.65,['수성동2가', '수성동3가']]
    },
    '북구': {
        '국우동': [17.19,['동호동', '학정동', '도남동', '국우동']],
        '관문동': [14.64,['노곡동', '매천동', '팔달동', '금호동', '사수동']],
        '무태조야동': [12.44,['조야동', '연경동']],
        '고성동': [0.53,['고성동1가', '고성동2가', '고성동3가']],
        '노원동':[3.09,['노원동1가', '노원동2가', '노원동3가']],
        '칠성동': [1.36,['칠성동1가', '칠성동2가']]
    },
    '동구': {
        '안심1동': [3.34,['신기동', '율하동']],
        '안심2동': [13.54,['용계동', '율암동', '상매동', '매여동']],
        '안심3동': [6.1,['괴전동', '금강동', '대림동', '사복동', '숙천동', '동호동', '신서동']],
        '안심4동': [2.6,['서호동', '각산동']],
        '공산동': [83.7,['능성동', '진인동', '도학동', '백안동', '미곡동', '용수동', '신무동', '미대동', '내동', '신용동', '중대동', '송정동', '덕곡동', '지묘동']],
        '불로.봉무동': [7.78,['봉무동', '불로동', '지저동']],
        '도평동': [19.23,['평광동', '도동']],
        '동촌동':[5.34,['입석동', '검사동']],
        '해안동': [13.29,['방촌동', '둔산동', '부동', '신평동']]
    },
    '중구': {
        '성내1동': [0.9,['봉산동', '덕산동', '사일동', '남일동', '동성로3가', '동문동', '문화동', '공평동', '동성로2가', '태평로1가', 
                      '교동', '완전동', '포정동', '동성로1가', '화전동']],
        '성내2동': [0.76,['장관동', '상서동', '수동', '종로1가', '종로2가', '동일동', '전동', '수창동', '태평로3가', '서성로1가', 
                       '하서동', '남성로', '계산동1가', '계산동2가', '동산동', '서성로2가', '서문로1가', '북성로2가', '대안동', 
                       '태평로2가', '북성로1가', '향촌동']],
        '성내3동': [0.79,['도원동', '인교동', '서야동', '시장북로', '서문로2가', '달성동']],
        '삼덕동': [0.64,['삼덕동1가', '삼덕동2가', '삼덕동3가']]
    },
    '달서구': {
        '장기동': [3.11,['장동', '장기동']],
        '월성1동': [8.89,['대천동', '월성동', '월암동', '유천동']],
        '진청동': [5.97,['진천동', '대곡동']],
        '신당동': [9.38,['파호동', '호림동', '갈산동', '신당동', '호산동']]
    }
}


dubble_check = {'남구':{'이천동':1.09},'달서구':{'도원동':10.64}}
area_data ={'대신동':0.52, '감삼동':1.18, '두산동':1.97, '복현동':2.26, '신암동':3.26, '지산동':4.61, '상인동':5.97, '태전동':4.41, 
       '평리동':3.33, '황금동':3.85, '구암동':4.4, '신천동':1.95, '만촌동':6.28, '남산동':1.61,'비산동':4.81, '침산동':3.27, '두류동':2.44,
       '유가읍':57.25, '논공읍':43.89, '다사읍':36.65,  '수성동4가':0.63, '서변동':7.4, '관음동':2.99, '파동':5.82, '상동':1.33, 
       '이곡동':3.86, '효목동':2.1, '읍내동':5.71,  '죽전동':0.74, '대명동':10.1, '동천동':1.12,'본리동':1.09,  '범어동':3.87, 
       '성당동':1.99, '용산동':2.55,'가창면':111.17,'산격동':4.74,  '현풍읍':24.47, '구지면':39.75, '송현동':3.43, '봉덕동':6.25, 
        '대현동':1.22, '대봉동':0.84, '본동':1.1, '검단동':3.91, '화원읍':27.68, '중동':0.91,'하빈면':36.7, '동인동1가':0.18, 
        '내당동':1.87,  '옥포읍':48.94, '동인동4가':0.27, '수성동1가':0.58, '동변동':3.4, '범물동':7.77,'동인동2가':0.2,  
        '동인동3가':0.34, '북성로1가':0.9, }

# %%
# 추가되는 컬럼 : 행정동군 , 면적
for gu, dongs in group_area.items():
    for group, dongs in dongs.items():
        for dong in dongs[1]:
            condition = (light_df['구'] == gu) & (light_df['동'] == dong)
            # 찾은 행의 'group' 컬럼에 값을 넣습니다.
            light_df.loc[condition, '행정동군'] = group
            light_df.loc[condition, '면적'] = dongs[0]

for gu, dong_data in dubble_check.items():
    for dong, value in dong_data.items():
        condition = (light_df['구'] == gu) & (light_df['동'] == dong)
        light_df.loc[condition, '면적'] = value

for area, value in area_data.items():
    condition = (light_df['동'] == area)
    light_df.loc[condition, '면적'] = value
light_df
# Out:
#         도시    구      동  설치개수  행정동군     면적
# 0    대구광역시   남구    대명동  5377   NaN  10.10
# 1    대구광역시   남구    봉덕동  1424   NaN   6.25
# 2    대구광역시   남구    이천동   556   NaN   1.09
# 3    대구광역시  달서구    갈산동   349   신당동   9.38
# 4    대구광역시  달서구    감삼동   932   NaN   1.18
# ..     ...  ...    ...   ...   ...    ...
# 223  대구광역시   중구  태평로2가    38  성내2동   0.76
# 224  대구광역시   중구  태평로3가    47  성내2동   0.76
# 225  대구광역시   중구    포정동    18  성내1동   0.90
# 226  대구광역시   중구    향촌동    28  성내2동   0.76
# 227  대구광역시   중구    화전동    22  성내1동   0.90
#
# [228 rows x 6 columns]

# %%
def min_max_normalize(x):
    return (x - x.min()) / (x.max() - x.min())

light_df=light_df[light_df['면적'].isna()==False]
light_df['행정동군별설치개수'] = light_df.groupby('행정동군')['설치개수'].transform('sum')
light_df['총개수']=light_df['행정동군별설치개수'].copy()
light_df['총개수'][light_df['행정동군'].isna()] = light_df['설치개수']
light_df['밀도'] = light_df['총개수'] / light_df['면적']
light_df['정규화밀도'] = min_max_normalize(light_df['밀도'])
light_df.reindex()
light_df
# Out:
# C:\Users\hyundong\AppData\Local\Temp\ipykernel_24508\1485746370.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   light_df['총개수'][light_df['행정동군'].isna()] = light_df['설치개수']
#         도시    구      동  설치개수  행정동군     면적  행정동군별설치개수     총개수           밀도  \
# 0    대구광역시   남구    대명동  5377   NaN  10.10        NaN  5377.0   532.376238
# 1    대구광역시   남구    봉덕동  1424   NaN   6.25        NaN  1424.0   227.840000
# 2    대구광역시   남구    이천동   556   NaN   1.09        NaN   556.0   510.091743
# 3    대구광역시  달서구    갈산동   349   신당동   9.38     1636.0  1636.0   174.413646
# 4    대구광역시  달서구    감삼동   932   NaN   1.18        NaN   932.0   789.830508
# ..     ...  ...    ...   ...   ...    ...        ...     ...          ...
# 223  대구광역시   중구  태평로2가    38  성내2동   0.76      752.0   752.0   989.473684
# ...

# %%
light_df
# Out:
#         도시    구      동  설치개수  행정동군     면적  행정동군별설치개수     총개수           밀도  \
# 0    대구광역시   남구    대명동  5377   NaN  10.10        NaN  5377.0   532.376238
# 1    대구광역시   남구    봉덕동  1424   NaN   6.25        NaN  1424.0   227.840000
# 2    대구광역시   남구    이천동   556   NaN   1.09        NaN   556.0   510.091743
# 3    대구광역시  달서구    갈산동   349   신당동   9.38     1636.0  1636.0   174.413646
# 4    대구광역시  달서구    감삼동   932   NaN   1.18        NaN   932.0   789.830508
# ..     ...  ...    ...   ...   ...    ...        ...     ...          ...
# 223  대구광역시   중구  태평로2가    38  성내2동   0.76      752.0   752.0   989.473684
# 224  대구광역시   중구  태평로3가    47  성내2동   0.76      752.0   752.0   989.473684
# 225  대구광역시   중구    포정동    18  성내1동   0.90     1147.0  1147.0  1274.444444
# 226  대구광역시   중구    향촌동    28  성내2동   0.76      752.0   752.0   989.473684
# 227  대구광역시   중구    화전동    22  성내1동   0.90     1147.0  1147.0  1274.444444
#
#         정규화밀도
# 0    0.082315
# 1    0.034459
# 2    0.078813
# 3    0.026064
# ...

# %% [markdown]
# """
# -서구
# 상중이동 : 상리동, 중리동, 이현동
# 원대동 : 원대동1가, 원대동2가, 원대동3가
#
# -수성구
# 고산동1동 : 신매동 + 욱수동
# 고산2동 : 시지동, 노변동, 삼덕동, 연호동, 이천동, 고모동, 가천동, 대흥동
# 고산3동 : 매호동, 성동, 사월동
# 수성2,3가동 : 수성동2가, 수성동3가
#
#
# - 북구
# 국우동 : 동호동, 학정동, 도남동, 국우동
# 관문동 : 노곡동, 매천동, 팔달동, 금호동, 사수동
# 무태조야동: 조야동, 연경동
# 고성동 : 	고성동1가, 고성동2가, 고성동3가
# 노원동 : 노원동1가, 노원동2가, 노원동3가
# 칠성동 :   '칠성동1가', '칠성동2가'
#
#
# - 동구
# 안심1동 : 신기동, 율하동
# 안심2동 : 용계동, 율암동, 상매동, 매여동
# 안심3동 : 괴전동, 금강동, 대림동, 사복동, 숙천동, 동호동, 신서동
# 안심4동 : 서호동,  각산동
# 공산동 : 능성동, 진인동, 도학동, 백안동, 미곡동, 용수동, 신무동, 미대동, 내동, 신용동, 중대동, 송정동, 덕곡동, 지묘동
# 불로.봉무동 : 봉무동, 불로동, 지저동
# 도평동 : 평광동, 도동
# 동촌동 : 입석동, 검사동
# 해안동 : 방촌동, 둔산동, 부동, 신평동
#
#
# - 중구
# 성내1동 : 봉산동, 덕산동, 사일동, 남일동, 동성로3가, 동문동, 문화동, 공평동, 동성로2가, 태평로1가, 교동, 완전동, 포정동, 동성로1가,  화전동
# 성내2동 : 장관동, 상서동, 수동,  종로1가, 종로2가, 동일동,  전동, 수창동, 태평로3가, 서성로1가, 하서동, 남성로, 계산동1가, 계산동2가, 동산동, 서성로2가, 서문로1가, 북성로2가, 대안동, 태평로2가, 북성로1가, 화전동, 향촌동, 북내동
# 성내3동 : 도원동,  인교동, 서야동,  시장북로,  서문로2가, 달성동
# 삼덕동 : '삼덕동1가','삼덕동2가','삼덕동3가'
# 동인동 : '동인동1가',  '동인동4가','동인동2가','동인동3가'
#
# -달서구
#
# 장기동 : 장동, 장기동(일부)
# 월성1동 : 대천동, 월성동, 월암동, 유천동
# 진청동 : 진천동, 대곡동
# 신당동: 파호동, 호림동, 갈산동, 신당동, 호산동
# """
#
# """
#
#
# dubble_check = {'남구':{'이천동':1.09},'달서구':{'도원동':10.64},'동구':{'동호동':6.1},'북구':{'동호동':17.19},'수성구':{'이천동':24.39},'중구':{'도원동':0.79}}
# area_data ={'대신동':0.52, '감삼동':1.18, '두산동':1.97, '복현동':2.26, '신암동':3.26, '지산동':4.61, '상인동':5.97, '태전동':4.41, '지묘동':83.70,
#        '평리동':3.33, '신기동':3.34, '상리동':6.69, '월성동':8.89, '황금동':3.85, '구암동':4.4, '신천동':1.95, '만촌동':6.28, '남산동':1.61,
#        '비산동':4.81, '침산동':3.27, '두류동':2.44, '신매동':8.79, '대곡동':5.97, '유가읍':57.25, '논공읍':43.89, '율하동':3.34, '시지동':24.39,
#        '봉무동':7.78, '다사읍':36.65, '동산동':0.76, '이현동':6.69, '수성동4가':0.63, '노원동3가':3.09, '서변동':7.4, '관음동':2.99,
#        '학정동':17.19, '파동':5.82, '상동':1.33, '이곡동':3.86, '효목동':2.1, '읍내동':5.71, '남성로':0.76, '죽전동':0.74, '대명동':10.1, '동천동':1.12,
#        '지저동':7.78, '사수동':14.64, '덕산동':0.9, '본리동':1.09, '용계동':13.54, '범어동':3.87, '신당동':9.38, '성당동':1.99, '용산동':2.55,
#        '태평로3가':0.76, '도학동':83.70, '욱수동':8.79, '불로동':7.78, '칠성동1가':1.36, '장기동':3.11, '매호동':5.01, '대천동':8.89,
#        '삼덕동1가':0.64, '수성동2가':0.65, '팔달동':14.64, '삼덕동':24.39, '진천동':5.97, '수성동3가':0.65, '가창면':111.17, '방촌동':1.24,
#        '산격동':4.74, '월암동':8.89, '현풍읍':24.47, '구지면':39.75, '매천동':14.64, '송현동':3.43, '고성동3가':0.53, '봉덕동':6.25, '칠성동2가':1.36,
#        '공평동':0.9, '봉산동':0.9, '괴전동':6.1, '국우동':17.19, '대현동':1.22, '노원동1가':3.09, '대봉동':0.84, '본동':1.1, '신서동':6.1,
#        '검단동':3.91, '화원읍':27.68, '삼덕동2가':0.64, '입석동':5.34, '중동':0.91, '삼덕동3가':0.64, '파호동':9.38, '동내동':'null',
#        '하빈면':36.7, '율암동':13.54, '동인동1가':0.18, '내당동':1.87, '유천동':1.25, '호산동':9.38, '교동':0.9, '옥포읍':48.94, '원대동3가':0.62,
#        '검사동':5.34, '동인동4가':0.27, '수성동1가':0.58, '고성동2가':0.53, '각산동':2.6, '중리동':6.69, '고성동1가':0.53, '갈산동':9.38,
#        '대림동':6.1, '호림동':9.38, '연호동':24.39, '동변동':3.4, '범물동':7.77, '계산동2가':0.76, '동문동':0.9, '고모동':24.39, '금호동':14.64,
#        '장동':3.11, '수창동':0.76, '동인동2가':0.2, '가천동':24.39, '노변동':24.39, '달성동':0.79, '동인동3가':0.34, '서문로2가':0.79,
#        '동성로2가':0.9, '중대동':83.70, '사월동':5.01, '장관동':0.76, '신평동':12.05, '숙천동':6.1, '성동':5.01, '동일동':0.76, '시장북로':0.79,
#        '서호동':2.6, '용수동':83.70, '대흥동':24.39, '동성로3가':0.9, '연경동':12.44, '원대동1가':0.62, '남일동':0.9, '부동':12.05, '송정동':83.70,
#        '백안동':83.70, '도동':19.23, '인교동':0.79, '미대동':83.70, '노원동2가':3.09, '북성로1가':0.9, '조야동':12.44, '태평로2가':0.76, '포정동':0.9,
#        '노곡동':14.64, '진인동':83.70, '서문로1가':0.76, '덕곡동':83.70, '문화동':0.9, '상매동':13.54, '사복동':6.1, '종로1가':0.76, '계산동1가':0.76,
#        '상서동':0.76, '서성로1가':0.76, '원대동2가':0.62, '태평로1가':0.9, '미곡동':83.70, '사일동':0.9, '내동':83.70, '전동':0.76, '둔산동':12.5,
#        '매여동':13.54, '완전동':0.9, '북성로2가':0.76, '하서동':0.76, '화전동':0.9, '능성동':83.70, '서성로2가':0.76, '금강동':6.1, '향촌동':0.76,
#        '수동':0.76, '신무동':83.70, '대안동':0.76, '종로2가':0.76, '서야동':0.79, '신용동':83.70, '동성로1가':0.9, '평광동':19.23, '도남동':17.19}
# """
