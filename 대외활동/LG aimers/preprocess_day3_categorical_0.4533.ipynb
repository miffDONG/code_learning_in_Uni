# %% [markdown]
# # 영업 성공 여부 분류 경진대회

# %% [markdown]
# # 할 것
#
# 결측치 처리
# 파생변수 생성

# %% [markdown]
# ## 1. 데이터 확인

# %% [markdown]
# ### 필수 라이브러리

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def seed_everything(seed):
    np.random.seed(seed) #numpy를 사용할 경우 고정
seed_everything(42)

# %% [markdown]
# ### 데이터 셋 읽어오기

# %%
df_train = pd.read_csv("train.csv") # 학습용 데이터
df_test = pd.read_csv("submission.csv") # 테스트 데이터(제출파일의 데이터)

# %%
df_train.head()
# Out:
#    bant_submit          customer_country business_unit  com_reg_ver_win_rate  \
# 0          1.0  /Quezon City/Philippines            AS              0.066667
# 1          1.0        /PH-00/Philippines            AS              0.066667
# 2          1.0           /Kolkata /India            AS              0.088889
# 3          1.0        /Bhubaneswar/India            AS              0.088889
# 4          1.0          /Hyderabad/India            AS              0.088889
#
#    customer_idx          customer_type  enterprise  historical_existing_cnt  \
# 0         32160           End-Customer  Enterprise                      NaN
# 1         23122           End-Customer  Enterprise                     12.0
# 2          1755           End-Customer  Enterprise                    144.0
# 3          4919           End-Customer  Enterprise                      NaN
# 4         17126  Specifier/ Influencer  Enterprise                      NaN
#
#    id_strategic_ver  it_strategic_ver  idit_strategic_ver  \
# 0               NaN               NaN                 NaN
# 1               NaN               NaN                 NaN
# 2               NaN               NaN                 NaN
# 3               NaN               NaN                 NaN
# 4               NaN               NaN                 NaN
#
#               customer_job  lead_desc_length  \
# 0               purchasing                62
# 1  media and communication                96
# 2              engineering                56
# 3         entrepreneurship                44
# 4               consulting                97
#
#                          inquiry_type product_category product_subcategory  \
# 0  Quotation or purchase consultation      multi-split                 NaN
# 1  Quotation or purchase consultation      multi-split                 NaN
# 2                 Product Information     single-split                 NaN
# 3  Quotation or purchase consultation              vrf                 NaN
# 4  Quotation or purchase consultation      multi-split                 NaN
#
#   product_modelname        customer_country.1 customer_position  \
# 0               NaN  /Quezon City/Philippines       entry level
# 1               NaN        /PH-00/Philippines       ceo/founder
# 2               NaN           /Kolkata /India           partner
# 3               NaN        /Bhubaneswar/India       ceo/founder
# 4               NaN          /Hyderabad/India           partner
#
#   response_corporate   expected_timeline  ver_cus  ver_pro  ver_win_rate_x  \
# 0              LGEPH  less than 3 months        1        0        0.003079
# 1              LGEPH  less than 3 months        1        0        0.003079
# 2              LGEIL  less than 3 months        1        0        0.003079
# 3              LGEIL  less than 3 months        1        0        0.003079
# 4              LGEIL  less than 3 months        0        0        0.003079
#
#    ver_win_ratio_per_bu       business_area business_subarea  lead_owner  \
# 0              0.026846  corporate / office      Engineering           0
# 1              0.026846  corporate / office      Advertising           1
# 2              0.026846  corporate / office     Construction           2
# 3              0.026846  corporate / office      IT/Software           3
# 4              0.026846  corporate / office              NaN           4
#
#    is_converted
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True

# %%
df_test.columns
# Out:
# Index(['id', 'bant_submit', 'customer_country', 'business_unit',
#        'com_reg_ver_win_rate', 'customer_idx', 'customer_type', 'enterprise',
#        'historical_existing_cnt', 'id_strategic_ver', 'it_strategic_ver',
#        'idit_strategic_ver', 'customer_job', 'lead_desc_length',
#        'inquiry_type', 'product_category', 'product_subcategory',
#        'product_modelname', 'customer_country.1', 'customer_position',
#        'response_corporate', 'expected_timeline', 'ver_cus', 'ver_pro',
#        'ver_win_rate_x', 'ver_win_ratio_per_bu', 'business_area',
#        'business_subarea', 'lead_owner', 'is_converted'],
#       dtype='object')

# %%
# 결측치가 있는 변수 및 결측률 파악 

mis_val = df_train.isnull().sum()
mis_val_bool = mis_val >= 1
mis_val_df = pd.concat([mis_val, mis_val_bool], axis = 1)
mis_val_df = mis_val_df.rename(columns = {0 : 'mis_val', 1 : 'mis_val_bool'})

mis_val_data = mis_val_df.loc[mis_val_df['mis_val_bool'] == True, :]
mis_val_data['ratio'] = mis_val_data['mis_val'] / 59299
mis_val_data_sorted = mis_val_data.sort_values(by='ratio', ascending=True)
mis_val_data_sorted
# Out:
# /tmp/ipykernel_53/929980573.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis_val_data['ratio'] = mis_val_data['mis_val'] / 59299
#                          mis_val  mis_val_bool     ratio
# inquiry_type                 941          True  0.015869
# customer_country.1           982          True  0.016560
# customer_country             982          True  0.016560
# customer_job               18733          True  0.315908
# product_category           19374          True  0.326717
# expected_timeline          30863          True  0.520464
# business_area              40882          True  0.689421
# ver_win_rate_x             40882          True  0.689421
# customer_type              43961          True  0.741345
# ver_win_ratio_per_bu       43995          True  0.741918
# com_reg_ver_win_rate       44731          True  0.754330
# historical_existing_cnt    45543          True  0.768023
# product_subcategory        50064          True  0.844264
# product_modelname          50070          True  0.844365
# business_subarea           53773          True  0.906811
# idit_strategic_ver         54734          True  0.923017
# id_strategic_ver           55855          True  0.941921
# it_strategic_ver           58178          True  0.981096

# %%
# idit_strategic_ver , it_strategic_ver , id_strategic_ver 세 columns 값들이 array([nan,  1.])
# historical_existing_cnt nan = 0

#inquiry_type - 대소문자 통합 -> 전부 소문자로

# print(df_train['customer_type'].str.lower().unique())
# print(df_train['customer_type'].unique())

# %%
# customer_country , customer_country.1의 값이 일치함.
df_train = df_train.drop(labels = ['customer_country.1'],axis=1)
df_test = df_test.drop(labels = ['customer_country.1','id'],axis=1)

dtypes = df_train.dtypes

# 각 열의 고유값 개수 확인
unique_value_counts = df_train.nunique()

# 수치형 변수가 아닌 컬럼을 저장할 리스트 초기화
object_columns = []

# 각 열에 대해 데이터 타입이 'object'이거나 고유값 개수가 일정 이하인 경우를 확인하여 non_numeric_columns 리스트에 추가
for col in df_train.columns:
    if dtypes[col] == 'object':
        object_columns.append(col)

# 수치형 변수가 아닌 컬럼 출력
print("수치형 변수가 아닌 컬럼:", object_columns)
# Out:
# 수치형 변수가 아닌 컬럼: ['customer_country', 'business_unit', 'customer_type', 'enterprise', 'customer_job', 'inquiry_type', 'product_category', 'product_subcategory', 'product_modelname', 'customer_position', 'response_corporate', 'expected_timeline', 'business_area', 'business_subarea']

# %% [markdown]
# ### 전처리
# inquiry_type,customer_country - 대소문자 통합
# customer_country 결측치 행 삭제

# %%
def preprocess_1(col):
    df_train[col] = df_train[col].str.lower()
    df_test[col] = df_test[col].str.lower()
    
    mask_train = df_train[col].notnull()
    mask_test = df_test[col].notnull()
    df_train.loc[mask_train, col] = df_train.loc[mask_train, col].apply(lambda x: x.replace(" ", ""))
    df_test.loc[mask_test, col] = df_test.loc[mask_test, col].apply(lambda x: x.replace(" ", ""))

# %%
for n in object_columns:
    preprocess_1(n)
#test data에 customer_country = nan 이 없어서 행삭제 해도 될듯. 삭제양도 많지 않음.
df_train = df_train.dropna(subset=['customer_country'])

# 보류
# df_train['customer_country'] = df_train['customer_country'].apply(lambda x: x.split('/')[-1])
# df_test['customer_country'] = df_test['customer_country'].apply(lambda x: x.split('/')[-1])

# %%
print(df_train['inquiry_type'].unique())
# Out:
# ['quotationorpurchaseconsultation' 'productinformation' 'other'
#  'usageortechnicalconsultation' 'trainings' 'services' 'salesinquiry'
#  'etc.' 'technicalsupport' 'technicalconsultation' 'requestforpartnership'
#  nan 'sales' 'technical' 'other_' 'quotation_or_purchase_consultation'
#  'requestademo' 'requestfordistributorship'
#  'requestforquotationorpurchase' 'requestfortechnicalconsulting'
#  '(selectid_needs)' 'aio' 'needs' 'purchase' 'technical_consultation'
#  'customersuggestions' 'eventinquiry' 'others' 'oem/odmrequest'
#  'hospitaltv' 'iwanttoknowthedetailsaboutit' 'educationalequipments'
#  'digitalplatform' 'tvinteractive' 'teach' 'displaytextbookandphotos'
#  'quotation_' 'purchaseorquotation' 'displayproduct' 'firstinfoandpricing'
#  'estoybuscandoparaecuadoresteproductolgmagnitmicroled,paraunclientede138pulgadas,conenviómarítimo.'
#  'holamepuedencotizar19pantallasinteractivasde100pulgadasentregadasenguayaquil-ecuador.'
#  'probeamprecio' 'hoteltvproducts' 'pantallasinteractivasparaclinicas'
#  'solicitoapoyopararealizarcotizaciondelosdispositivosqueofrecenenlasolución\xa0onequick:\xa0'
#  'forschool' 'mediainquiry' 'tôicầnthamkhảogiávàgiảipháptừlg' 'vrf'
#  'evento_sdelestero']

# %% [markdown]
# ### 레이블 인코딩

# %%
def label_encoding(series: pd.Series) -> pd.Series:
    """범주형 데이터를 시리즈 형태로 받아 숫자형 데이터로 변환합니다."""

    my_dict = {}

    # 모든 요소를 문자열로 변환
    series = series.astype(str)

    for idx, value in enumerate(sorted(series.unique())):
        my_dict[value] = idx
    series = series.map(my_dict)

    return series

# %%
# 레이블 인코딩할 칼럼들
label_columns = [
    "customer_country",
    "business_subarea",
    "business_area",
    "business_unit",
    "customer_type",
    "enterprise",
    "customer_job",
    "inquiry_type",
    "product_category",
    "product_subcategory",
    "product_modelname",
    "customer_position",
    "response_corporate",
    "expected_timeline",
]

# label_columns = list(set(label_columns)-set(drop_columns))

df_all = pd.concat([df_train[label_columns], df_test[label_columns]])

for col in label_columns:
    df_all[col] = label_encoding(df_all[col])

# %%
df_all.head()
# Out:
#    customer_country  business_subarea  business_area  business_unit  \
# 0              6870                27              0              0
# 1              6502                 0              0              0
# 2              4483                15              0              0
# 3              1449                46              0              0
# 4              3785                58              0              0
#
#    customer_type  enterprise  customer_job  inquiry_type  product_category  \
# 0              9           0           414            31               142
# 1              9           0           301            31               142
# 2              9           0           156            26               198
# 3              9           0           162            31               271
# 4             27           0            82            31               142
#
#    product_subcategory  product_modelname  customer_position  \
# 0                  140                654                 43
# 1                  140                654                 17
# 2                  140                654                 73
# 3                  140                654                 17
# 4                  140                654                 73
#
#    response_corporate  expected_timeline
# 0                  33                246
# 1                  33                246
# 2                  21                246
# 3                  21                246
# 4                  21                246

# %% [markdown]
# 다시 학습 데이터와 제출 데이터를 분리합니다.

# %%
for col in label_columns:  
    df_train[col] = df_all.iloc[: len(df_train)][col]
    df_test[col] = df_all.iloc[len(df_train):][col]

# %%
t = df_train.copy()
corr = t.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# /home/elicer/.local/lib/python3.10/site-packages/pandas/io/formats/style.py:3819: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /home/elicer/.local/lib/python3.10/site-packages/pandas/io/formats/style.py:3820: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_72e7a_row0_col0, #T_72e7a_row1_col1, #T_72e7a_row2_col2, #T_72e7a_row3_col3, #T_72e7a_row4_col4, #T_72e7a_row5_col5, #T_72e7a_row6_col6, #T_72e7a_row7_col7, #T_72e7a_row11_col11, #T_72e7a_row12_col12, #T_72e7a_row13_col13, #T_72e7a_row14_col14, #T_72e7a_row15_col15, #T_72e7a_row16_col16, #T_72e7a_row17_col17, #T_72e7a_row18_col18, #T_72e7a_row19_col19, #T_72e7a_row20_col20, #T_72e7a_row21_col21, #T_72e7a_row22_col22, #T_72e7a_row23_col23, #T_72e7a_row24_col24, #T_72e7a_row25_col25, #T_72e7a_row26_col26, #T_72e7a_row27_col27 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72e7a_row0_col1, #T_72e7a_row0_col15, #T_72e7a_row0_col16, #T_72e7a_row25_col18, #T_72e7a_row25_col23 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_72e7a_row0_col2, #T_72e7a_row6_col24, #T_72e7a_row14_col17, #T_72e7a_row24_col19, #T_72e7a_row27_col19, #T_72e7a_row27_col20 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T
{
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_72e7a_row0_col21, #T_72e7a_row1_col22, #T_72e7a_row2_col20, #T_72e7a_row4_col3, #T_72e7a_row5_col19, #T_72e7a_row7_col14, #T_72e7a_row16_col13, #T_72e7a_row25_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_72e7a_row0_col22, #T_72e7a_row6_col22, #T_72e7a_row17_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_72e7a_row0_col23, #T_72e7a_row15_col14, #T_72e7a_row20_col23, #T_72e7a_row23_col7, #T_72e7a_row24_col11, #T_72e7a_row26_col14 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_72e7a_row0_col24, #T_72e7a_row4_col22, #T_72e7a_row14_col19, #T_72e7a_row16_col3, #T_72e7a_row21_col23, #T_72e7a_row26_col24 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_72e7a_row0_col25, #T_72e7a_row1_col14, #T_72e7a_row6_col13, #T_72e7a_row7_col21, #T_72e7a_row11_col2, #T_72e7a_row12_col14, #T_72e7a_row20_col14, #T_72e7a_row21_col5, #T_72e7a_row21_col13, #T_72e7a_row27_col5, #T_72e7a_row27_col26 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_72e7a_row0_col27, #T_72e7a_row4_col26, #T_72e7a_row5_col26, #T_72e7a_row17_col15, #T_72e7a_row19_col12 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_72e7a_row1_col0, #T_72e7a_row4_col17, #T_72e7a_row17_col22, #T_72e7a_row25_col17 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_72e7a_row1_col2, #T_72e7a_row7_col0, #T_72e7a_row11_col1, #T_72e7a_row18_col21, #T_72e7a_row24_col2, #T_72e7a_row25_col14, #T_72e7a_row26_col27 {
#   background-color: #6e90f2;
#   color: #f1f1f

# %%
print(df_train.columns)
print('\n\n\n')
print(df_test.columns)
# Out:
# Index(['bant_submit', 'customer_country', 'business_unit',
#        'com_reg_ver_win_rate', 'customer_idx', 'customer_type', 'enterprise',
#        'historical_existing_cnt', 'id_strategic_ver', 'it_strategic_ver',
#        'idit_strategic_ver', 'customer_job', 'lead_desc_length',
#        'inquiry_type', 'product_category', 'product_subcategory',
#        'product_modelname', 'customer_position', 'response_corporate',
#        'expected_timeline', 'ver_cus', 'ver_pro', 'ver_win_rate_x',
#        'ver_win_ratio_per_bu', 'business_area', 'business_subarea',
#        'lead_owner', 'is_converted'],
#       dtype='object')
#
#
#
#
# Index(['bant_submit', 'customer_country', 'business_unit',
#        'com_reg_ver_win_rate', 'customer_idx', 'customer_type', 'enterprise',
#        'historical_existing_cnt', 'id_strategic_ver', 'it_strategic_ver',
#        'idit_strategic_ver', 'customer_job', 'lead_desc_length',
#        'inquiry_type', 'product_category', 'product_subcategory',
#        'product_modelname', 'customer_position', 'response_corporate',
#        'expected_timeline', 'ver_cus', 'ver_pro', 'ver_win_rate_x',
#        'ver_win_ratio_per_bu', 'business_area', 'business_subarea',
#        'lead_owner', 'is_converted'],
#       dtype='object')

# %% [markdown]
# ### 2-2. 학습, 검증 데이터 분리

# %%
x_train, x_val, y_train, y_val = train_test_split(
    df_train.drop("is_converted", axis=1),
    df_train["is_converted"],
    test_size=0.2,
    shuffle=True,
    random_state=400,
)

# %% [markdown]
# ## 3. 모델 학습

# %% [markdown]
# ### 모델 정의

# %%
model = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### 모델 학습

# %%
model.fit(x_train.fillna(0), y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ### 모델 성능 보기

# %%
def get_clf_eval(y_test, y_pred=None):
    confusion = confusion_matrix(y_test, y_pred, labels=[True, False])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, labels=[True, False])
    recall = recall_score(y_test, y_pred)
    F1 = f1_score(y_test, y_pred, labels=[True, False])

    print("오차행렬:\n", confusion)
    print("\n정확도: {:.4f}".format(accuracy))
    print("정밀도: {:.4f}".format(precision))
    print("재현율: {:.4f}".format(recall))
    print("F1: {:.4f}".format(F1))

# %%
pred = model.predict(x_val.fillna(0))
get_clf_eval(y_val, pred)
# Out:
# 오차행렬:
#  [[  765   191]
#  [  197 10511]]
#
# 정확도: 0.9667
# 정밀도: 0.7952
# 재현율: 0.8002
# F1: 0.7977

# %% [markdown]
# ## 4. 제출하기

# %% [markdown]
# ### 테스트 데이터 예측

# %%
# 예측에 필요한 데이터 분리
x_test = df_test.drop(["is_converted"], axis=1)

# %%
test_pred = model.predict(x_test.fillna(0))
sum(test_pred) # True로 예측된 개수
# Out:
# 889

# %% [markdown]
# ### 제출 파일 작성

# %%
# 제출 데이터 읽어오기 (df_test는 전처리된 데이터가 저장됨)
df_sub = pd.read_csv("submission.csv")
df_sub["is_converted"] = test_pred

# 제출 파일 저장
df_sub.to_csv("submission.csv", index=False)

# %% [markdown]
# **우측 상단의 제출 버튼을 클릭해 결과를 확인하세요**
